# %% [markdown]
# # QWEN3-1.7B Gradient Importance Analysis
#
# Cleaned notebook for all-organ gradient importance on the 1K-length QWEN3-1.7B model.

# %% [markdown]
# ## 1. Setup

# %%
# Runtime setup: Colab TPU environment, dependencies, and project data.
from google.colab import drive
import os
import shutil
import subprocess
import sys

os.environ['PJRT_DEVICE'] = 'TPU'
os.environ['XLA_USE_BF16'] = '1'
os.environ.setdefault('PT_XLA_DEBUG', '0')
os.environ.setdefault('TOKENIZERS_PARALLELISM', 'false')

drive.mount('/content/drive')

PYTORCH_VERSION = '2.6.0'
REPO_URL = "https://github.com/HangYu8123/SC_Ageing_Prediction.git"
TARGET_DIR = "/content/SC_Ageing_Prediction"
DATA_DIR = os.environ.get('SCAP_DATA_DIR', f'{TARGET_DIR}/fine_tune_chunks')


def pip_install(args):
    print('pip', ' '.join(args))
    subprocess.check_call([sys.executable, '-m', 'pip', *args])


def has_json_data(path):
    return os.path.isdir(path) and any(name.endswith('.json') for name in os.listdir(path))


try:
    import torch
    import torch_xla
    print('torch:', torch.__version__)
    print('torch_xla:', torch_xla.__version__)
except Exception as exc:
    print('Installing torch/torch_xla because import failed:', repr(exc))
    pip_install([
        '-q', 'install',
        f'torch=={PYTORCH_VERSION}',
        f'torch_xla[tpu]=={PYTORCH_VERSION}',
        '-f', 'https://storage.googleapis.com/libtpu-releases/index.html',
    ])

pip_install([
    '-q', 'install', '-U',
    'transformers>=4.45.0',
    'datasets>=2.19.0',
    'scikit-learn>=1.3.0',
    'peft>=0.12.0',
    'evaluate>=0.4.2',
    'wordcloud',
])

# Match the original notebook behavior: start fresh in /content, then clone the working repo.
if not has_json_data(DATA_DIR):
    if os.path.exists(TARGET_DIR):
        print('Removing existing TARGET_DIR before clone:', TARGET_DIR)
        shutil.rmtree(TARGET_DIR)
    subprocess.check_call(['git', 'clone', REPO_URL, TARGET_DIR])
    DATA_DIR = os.environ.get('SCAP_DATA_DIR', f'{TARGET_DIR}/data')
else:
    print('Using existing DATA_DIR:', DATA_DIR)

if not has_json_data(DATA_DIR):
    raise FileNotFoundError(
        f'No JSON files found in DATA_DIR: {DATA_DIR}. '
        'Set DATA_DIR or os.environ["SCAP_DATA_DIR"] to the folder containing the *_sorted.json files.'
    )

import gc
import glob
import inspect
import json
import pickle
import random
import time
from collections import Counter, defaultdict

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.runtime as xr
from datasets import Dataset, DatasetDict, load_dataset
from peft import LoraConfig, get_peft_model
from sklearn.metrics import classification_report, confusion_matrix
from transformers import AutoModelForSequenceClassification, AutoTokenizer, DataCollatorWithPadding
from wordcloud import WordCloud

xr.use_spmd()
if not hasattr(torch, 'xla'):
    torch.xla = torch_xla

try:
    import torch.utils.checkpoint
    import torch_xla.utils.checkpoint as xla_ckpt
    torch.utils.checkpoint.checkpoint = xla_ckpt.checkpoint
except Exception as exc:
    print('Checkpoint patch skipped:', repr(exc))

# %matplotlib inline
matplotlib.rcParams.update({
    'figure.dpi': 120,
    'figure.facecolor': 'white',
    'axes.facecolor': 'white',
})

print('PJRT device:', os.environ.get('PJRT_DEVICE'))
print('Global runtime device count:', xr.global_runtime_device_count())
print('XLA device:', torch_xla.device())
print('DATA_DIR:', DATA_DIR)
print('Setup complete.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# torch: 2.9.0+cpu
# torch_xla: 2.9.0
# pip -q install -U transformers>=4.45.0 datasets>=2.19.0 scikit-learn>=1.3.0 peft>=0.12.0 evaluate>=0.4.2 wordcloud
# Using existing DATA_DIR: /content/SC_Ageing_Prediction/fine_tune_chunks
# PJRT device: TPU
# Global runtime device count: 1
# XLA device: xla:0
# DATA_DIR: /content/SC_Ageing_Prediction/fine_tune_chunks
# Setup complete.

# %% [markdown]
# ## 2. Configuration

# %%
MODEL_ID = "Ha-ya/QWEN3-1.7B-EIGHT-ORGANS-EXTENDED-1K"
MAX_LENGTH = 1024
SEED = 42
DTYPE = torch.bfloat16

LABEL2ID = {'1m': 0, '3m': 1, '18m': 2, '24m': 3, '30m': 4}
ID2LABEL = {v: k for k, v in LABEL2ID.items()}
ORGAN_KEYS = ['bladder', 'brain', 'bone', 'limb', 'kidney', 'liver', 'lung', 'heart']
ALL_PARTS = list(range(1, 12))

# Runtime controls. Use SAMPLES_PER_ORGAN for a fast preview, then set it to None for the full run.
GRAD_TOPK = 100
GRAD_BATCH_SIZE = 8          # Try 12 or 16 if TPU memory allows; lower it if memory is tight.
SAMPLES_PER_ORGAN = None     # Example: 50 for a quick preview; None means all samples.
USE_TRUE_LABEL = True

# Save/reload paths. The expensive gradient run saves before any plotting.
RESULTS_DIR = '/content/drive/MyDrive/aging_prediction_results'
RESULTS_PKL = os.path.join(RESULTS_DIR, 'qwen3_1_7b_gradient_importance_results.pkl')
RESULTS_JSON = os.path.join(RESULTS_DIR, 'qwen3_1_7b_gradient_importance_results.json')

# Plot controls. Change these and rerun only the plotting cells.
PLOT_TOP_N = 100
PLOT_OUT_DIR = None          # Example: os.path.join(RESULTS_DIR, 'plots')
PLOT_BAR_COLOR = 'steelblue'
PLOT_WORDCLOUD_CMAP = 'plasma'
PLOT_FIGSIZE = (16, 20)


def set_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(SEED)
print('DTYPE:', DTYPE)
print('Results pickle:', RESULTS_PKL)
# Out:
# DTYPE: torch.bfloat16
# Results pickle: /content/drive/MyDrive/aging_prediction_results/qwen3_1_7b_gradient_importance_results.pkl

# %% [markdown]
# ## 3. Load Data

# %%
print('Files found:', len(glob.glob(f'{DATA_DIR}/*.json')))
print('Example files:', sorted(glob.glob(f'{DATA_DIR}/*.json'))[:5])


def load_json_dataset(files):
    try:
        return load_dataset('json', data_files=files, split='train')
    except Exception as exc:
        print('load_dataset(json) failed; falling back to manual JSON load. Error:', exc)
        rows = []
        for fp in files:
            with open(fp, 'r') as f:
                rows.extend(json.load(f))
        return Dataset.from_list(rows)


def organ_files(organ_name, parts=ALL_PARTS):
    return [f'{DATA_DIR}/{organ_name}_cell_data_part_{i}_sorted.json' for i in parts]


organ_file_map = {
    'bladder': organ_files('bladder'),
    'brain': organ_files('brain'),
    'bone': organ_files('bone-marrow'),
    'limb': organ_files('limb-muscle'),
    'kidney': organ_files('kidney'),
    'liver': organ_files('liver'),
    'lung': organ_files('lung'),
    'heart': organ_files('heart'),
}

organ_datasets = {organ: load_json_dataset(files) for organ, files in organ_file_map.items()}
all_files = [fp for files in organ_file_map.values() for fp in files]
eval_ds = load_json_dataset(all_files)

raw = DatasetDict({'validation': eval_ds, **organ_datasets})
print(raw)
print('Columns:', raw['validation'].column_names)
print('Example output label:', raw['validation'][0].get('output'))
print('\nPer-organ sizes:')
for split in ORGAN_KEYS:
    print(f'  {split}: {len(raw[split])} samples')
print(f"  TOTAL validation: {len(raw['validation'])} samples")
# Out:
# Files found: 199
# Example files: ['/content/SC_Ageing_Prediction/fine_tune_chunks/bladder_cell_data_part_1.json', '/content/SC_Ageing_Prediction/fine_tune_chunks/bladder_cell_data_part_10.json', '/content/SC_Ageing_Prediction/fine_tune_chunks/bladder_cell_data_part_10_sorted.json', '/content/SC_Ageing_Prediction/fine_tune_chunks/bladder_cell_data_part_11.json', '/content/SC_Ageing_Prediction/fine_tune_chunks/bladder_cell_data_part_11_sorted.json']
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Resolving data files:   0%|          | 0/88 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/88 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     validation: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 94239
#     })
#     bladder: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 7615
#     })
#     brain: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 19154
#     })
#     bone: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 25169
#     })
#     limb: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 17396
#     })
#     kidney: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 7262
#     })
#     liver: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 3859
#     })
#     lung: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 8992
#     })
#     heart: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 4792
#     })
# })
# Columns: ['instruction', 'input', 'output']
# Example output label: 18m
#
# Per-organ sizes:
#   bladder: 7615 samples
#   brain: 19154 samples
#   bone: 25169 samples
#   limb: 17396 samples
#   kidney: 7262 samples
#   liver: 3859 samples
#   lung: 8992 samples
#   heart: 4792 samples
#   TOTAL validation: 94239 samples

# %% [markdown]
# ## 4. Prepare Text and Labels

# %%
def format_text(example):
    instruction = (example.get('instruction') or '').strip()
    inp = (example.get('input') or '').strip()

    prefix = instruction + '\n\n'
    suffix = '\n\nAnswer with exactly one label from {1m, 3m, 18m, 24m, 30m}.'
    text = prefix + inp + suffix

    y = (example.get('output') or '').strip()
    if y not in LABEL2ID:
        raise ValueError(f'Unexpected label: {y}')

    return {
        'text': text,
        'label': LABEL2ID[y],
        'inp_start_char': len(prefix),
        'inp_end_char': len(prefix) + len(inp),
    }


raw = raw.map(format_text, remove_columns=raw['validation'].column_names)
print(raw['validation'][0])
# Out:
# Map:   0%|          | 0/94239 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7615 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19154 [00:00<?, ? examples/s]
# Map:   0%|          | 0/25169 [00:00<?, ? examples/s]
# Map:   0%|          | 0/17396 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7262 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3859 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8992 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4792 [00:00<?, ? examples/s]
# {'text': 'We will give you a sequence of scRNA transcriptomics data of a single cell. We would like to predict the age of the cell based on the gene name. The age is usually decided by combination of genes. The following are the gene names (Genes), gender (Gender), cell type (Class), and organ (Tissue), separated by the keywords Genes, Gender, Class, and Tissue. Different cell type (Class) has different combinations from each other.\n\nGenes: 4930487H11Rik three Adam23 three Col6a3 three Gli2 three Tnfaip3 three Snora33 three Rnf217 three Prdm1 three Dnmt3l three Ccdc157 three Lif three Zfp354c three Nlgn2 three Mpp2 three Axin2 three Abca5 three Colec11 three Rad51l1 three Jdp2 three Lrrc16a three Ccno three E130203B14Rik three Tpt1 three Clec16a three AI480653 three Epha3 three Thbs2 three Pou5f1 three 9130008F23Rik three 1110012J17Rik three Cdh2 three Fau three Pla2r1 three Tfpi three Creb3l1 three Nat10 three Bdnf three Rnf24 three Ninl three Ptgis three B4galt5 three Atp9a three Dkk2 three Whrn three Tnc three Bnc2 three Slc35d1 three C77080 three Mmp23 three Dcun1d4 three Ereg three Pcgf3 three Dennd2a three Mical3 three Leprel2 three Rtn2 three Cpeb1 three Dchs1 three Olfml1 three Spon1 three Sh3rf1 three Tbx20 three Prss35 three Gorasp1 three Phka1 three Ptp4a1 two Bag2 two Col3a1 two Col5a2 two Spats2l two Chpf two Gpc1 two Pfkfb2 two Pla2g4a two Mpzl1 two Ddr2 two Adamts4 two Grem2 two Plagl1 two Moxd1 two Ipmk two Col6a2 two Col6a1 two D10Wsu102e two Dcn two Csrp2 two Aebp1 two Cnrip1 two Wdr92 two Efemp1 two C1qtnf2 two Adamts2 two Smcr8 two Rab34 two Ypel2 two Col1a1 two Copz2 two Fkbp10 two Tex2 two Cdr2l two 1810032O08Rik two C1qtnf1 two Osr1 two Cys1 two Fam110c two Lamb1 two Fam179b two Map4k5 two Fbln5 two Serpina3n two AW555464 two Phf2 two Cxcl14 two Habp4 two Vcan two Arsb two Polk two Zswim6 two Pde4d two Plk2 two Nr1d2 two Plac9 two Mustn1 two Mapk8 two Samd4 two Pnp two Ang two Zfp219 two Slc7a8 two Parp4 two Bmp1 two 0610007N19Rik two Wisp1 two Lynx1 two Igfbp6 two Vasn two Mzt2 two Scarf2 two Pdia5 two Fstl1 two Tmem39a two Ccdc80 two Phldb2 two Col8a1 two Smoc2 two Rps10 two Pi16 two Hspa1b two Tmem63b two Vegfa two Mdfi two Kdm4b two Tnfsf9 two Twsg1 two Bambi two Colec12 two Impact two Dpysl3 two Ppic two 2010002N04Rik two Rps14 two Mbd1 two 1810055G02Rik two Rbm4b two Fosl1 two Efemp2 two Ltbp3 two Atg2a two Pcsk5 two Kazald1 two Grk5 two Itih5 two Plxdc2 two Npdc1 two Col5a1 two Ptges two Fmnl2 two Acvr1 two Cd302 two Sestd1 two Frzb two Serping1 two Mdk two Gm13889 two Rcn1 two Vps18 two Slc30a4 two Slc20a1 two Bmp2 two Rbbp9 two Srxn1 two Mcts2 two Myl9 two Blcap two Wfdc2 two Tshz2 two Nkain4 two Zbtb10 two Car3 two Lhfp two Sh3d19 two Ivl two Arnt two Ptgfrn two Igsf3 two Olfml3 two Col11a1 two Pitx2 two Hs2st1 two Tesk1 two Rgp1 two Tgfbr1 two Ugcg two Ttc39b two Podn two Gpx7 two Mob3c two Slc6a9 two Col16a1 two Nbl1 two Fbxo42 two Pdpn two Slc25a33 two Klhl21 two Mxra8 two Fzd1 two Il6 two Emilin1 two Fndc4 two Spon2 two Wfs1 two Pcdh7 two Fam114a1 two Ptpn13 two Pkd2 two Gbp6 two Tgfbr3 two Tmem175 two Hspb8 two Fam109a two Niacr1 two Tmem120a two Serpine1 two Trip6 two Pcolce two Col1a2 two Wnt2 two Hilpda two Smo two Cald1 two Slc37a3 two Rarres2 two Avl9 two Hk2 two Podxl2 two C1ra two Gprc5a two Rpl28 two Pvrl2 two Gsk3a two Erf two Axl two Sipa1l3 two Zdhhc13 two Man2a2 two Gab2 two P2ry2 two Sbf2 two Tead1 two Pde3b two Il4ra two Nupr1 two Tacc2 two Htra1 two Ifitm1 two Col4a2 two Gas6 two Plat two Gpr124 two Psd3 two Hhip two Mmp2 two Wfdc1 two Crispld2 two Sipa1l2 two Pard3 two Jam3 two 9030425E11Rik two Tagln two Nnmt two Ube2q2 two Aldh1a2 two Gclc two Irak1bp1 two Chst2 two Rbp1 two Ryk two Sema3f two Lamb2 two Scap two Nradd two Crtap two Fhl1 two Zfp275 two Bgn two Tceal8 two Prelp one Gfpt2 one Krt19 one Gadd45g one Krt18 one Has1 one Tubb6 one Sprr1a one Akap2 one Inmt one Tacstd2 one C1s one Fxyd1 one Serpinh1 one\nGender: male\nClass: bladder cell\nTissue: Bladder\n\nAnsw ...

# %% [markdown]
# ## 5. Tokenize

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True, trust_remote_code=True)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'right'
if tokenizer.bos_token_id is None and tokenizer.eos_token_id is not None:
    tokenizer.bos_token = tokenizer.eos_token

print('Tokenizer pad_token:', tokenizer.pad_token)
print('Tokenizer vocab size:', tokenizer.vocab_size)


def tok_fn(batch):
    enc = tokenizer(
        batch['text'],
        truncation=True,
        max_length=MAX_LENGTH,
        padding='max_length',
        return_offsets_mapping=True,
    )

    inp_token_masks = []
    for i in range(len(batch['text'])):
        start = batch['inp_start_char'][i]
        end = batch['inp_end_char'][i]
        mask = [1 if tok_start < end and tok_end > start else 0
                for tok_start, tok_end in enc['offset_mapping'][i]]
        inp_token_masks.append(mask)

    enc['inp_token_mask'] = inp_token_masks
    enc['labels'] = batch['label']
    del enc['offset_mapping']
    return enc


tok = raw.map(tok_fn, batched=True, remove_columns=raw['validation'].column_names)
print('Tokenized splits:', list(tok.keys()))
for split in tok.keys():
    print(f'  {split}: {len(tok[split])} samples')
print('tok ready.')
# Out:
# config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/704 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.6M [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/4.17k [00:00<?, ?B/s]
# Tokenizer pad_token: <|endoftext|>
# Tokenizer vocab size: 151643
# Map:   0%|          | 0/94239 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7615 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19154 [00:00<?, ? examples/s]
# Map:   0%|          | 0/25169 [00:00<?, ? examples/s]
# Map:   0%|          | 0/17396 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7262 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3859 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8992 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4792 [00:00<?, ? examples/s]
# Tokenized splits: ['validation', 'bladder', 'brain', 'bone', 'limb', 'kidney', 'liver', 'lung', 'heart']
#   validation: 94239 samples
#   bladder: 7615 samples
#   brain: 19154 samples
#   bone: 25169 samples
#   limb: 17396 samples
#   kidney: 7262 samples
#   liver: 3859 samples
#   lung: 8992 samples
#   heart: 4792 samples
# tok ready.

# %% [markdown]
# ## 6. Load Model and LoRA

# %%
def guess_lora_targets(model: torch.nn.Module):
    common = ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj']
    present = set()
    for name, module in model.named_modules():
        if isinstance(module, torch.nn.Linear):
            present.update(k for k in common if name.endswith(k))
    return sorted(present or {'q_proj', 'v_proj'})


model_kwargs = {
    'num_labels': len(LABEL2ID),
    'id2label': ID2LABEL,
    'label2id': LABEL2ID,
    'trust_remote_code': True,
}
sig = inspect.signature(AutoModelForSequenceClassification.from_pretrained)
model_kwargs['dtype' if 'dtype' in sig.parameters else 'torch_dtype'] = DTYPE

model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID, **model_kwargs)
model.config.use_cache = False
model.config.pad_token_id = tokenizer.pad_token_id
if getattr(model.config, 'bos_token_id', None) is None and tokenizer.bos_token_id is not None:
    model.config.bos_token_id = tokenizer.bos_token_id
if hasattr(model, 'generation_config') and getattr(model.generation_config, 'bos_token_id', None) is None:
    model.generation_config.bos_token_id = tokenizer.bos_token_id

print('Model loaded:', MODEL_ID, '| num_labels:', model.config.num_labels)

lora_targets = sorted(set(guess_lora_targets(model) + ['embed_tokens']))
print('LoRA target_modules:', lora_targets)

lora_config = LoraConfig(
    r=32,
    lora_alpha=64,
    lora_dropout=0.05,
    bias='none',
    task_type='SEQ_CLS',
    target_modules=lora_targets,
)
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
model.config.use_cache = False

data_collator = DataCollatorWithPadding(tokenizer=tokenizer, pad_to_multiple_of=128)
device = torch_xla.device()
model = model.to(device)
torch_xla.sync()
print(f'Model on device: {device}')
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.53G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Model loaded: Ha-ya/QWEN3-1.7B-EIGHT-ORGANS-EXTENDED-1K | num_labels: 5
# LoRA target_modules: ['down_proj', 'embed_tokens', 'gate_proj', 'k_proj', 'o_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable params: 40,522,048 || all params: 1,807,134,016 || trainable%: 2.2423
# Model on device: xla:0

# %% [markdown]
# ## 7. Evaluation Helpers

# %%
def _get_logits(predictions):
    # Some models return tuple/list; keep logits only
    if isinstance(predictions, (tuple, list)):
        return predictions[0]
    return predictions

labels_sorted = sorted(list(ID2LABEL.keys()))
label_names = [ID2LABEL[i] for i in labels_sorted]

# ------------------------------
# Subset -> validation index mapping helpers
# ------------------------------

_ID_CANDIDATES = ["id", "idx", "guid", "example_id", "uid", "record_id"]

def _try_get_indices_from__indices(subset_ds):
    """
    If subset_ds was produced from a parent dataset via .select/.filter,
    HF Datasets often stores the parent indices in subset_ds._indices.
    Returns np.ndarray[int64] or None.
    """
    idx_tbl = getattr(subset_ds, "_indices", None)
    if idx_tbl is None:
        return None

    try:
        # datasets.table.Table supports .column_names and .column(i)
        col_names = getattr(idx_tbl, "column_names", None)
        if col_names and len(col_names) > 0:
            # Prefer a column literally named "indices" if present, else first column
            if "indices" in col_names:
                col = idx_tbl.column(col_names.index("indices"))
            else:
                col = idx_tbl.column(0)
            idx_list = col.to_pylist()
            return np.asarray(idx_list, dtype=np.int64)
    except Exception:
        pass

    # Some versions may store as dict-like
    try:
        if hasattr(idx_tbl, "to_pydict"):
            d = idx_tbl.to_pydict()
            if "indices" in d:
                return np.asarray(d["indices"], dtype=np.int64)
            # fallback: first key
            if len(d) > 0:
                k0 = list(d.keys())[0]
                return np.asarray(d[k0], dtype=np.int64)
    except Exception:
        pass

    return None

def _pick_id_column(ds):
    cols = set(getattr(ds, "column_names", []))
    for c in _ID_CANDIDATES:
        if c in cols:
            return c
    return None

def _try_get_indices_from_id_column(subset_ds, parent_ds):
    """
    If both parent and subset share a stable ID column, build mapping parent_id -> index.
    Returns np.ndarray[int64] or None.
    """
    parent_id_col = _pick_id_column(parent_ds)
    subset_id_col = _pick_id_column(subset_ds)
    if parent_id_col is None or subset_id_col is None or parent_id_col != subset_id_col:
        return None

    id_col = parent_id_col
    try:
        parent_ids = parent_ds[id_col]
        subset_ids = subset_ds[id_col]
    except Exception:
        return None

    # Build parent map (first occurrence wins)
    id2i = {}
    for i, v in enumerate(parent_ids):
        if v not in id2i:
            id2i[v] = i

    idx = []
    missing = 0
    for v in subset_ids:
        if v in id2i:
            idx.append(id2i[v])
        else:
            missing += 1

    if missing > 0:
        # If anything is missing, mapping is unreliable
        return None

    return np.asarray(idx, dtype=np.int64)

def get_subset_indices_in_validation(subset_ds, validation_ds):
    """
    Returns indices into validation_ds corresponding to subset_ds, or None if cannot map.
    """
    idx = _try_get_indices_from__indices(subset_ds)
    if idx is not None:
        return idx

    idx = _try_get_indices_from_id_column(subset_ds, validation_ds)
    if idx is not None:
        return idx

    return None

# ------------------------------
# Core evaluation from arrays (no extra inference)
# ------------------------------

def evaluate_from_arrays(split_name: str, y_true: np.ndarray, logits: np.ndarray, metrics: dict = None):
    """
    Compute confusion matrix, per-label recall (row-wise acc), and classification report
    from already-available y_true and logits.
    """
    y_true = np.asarray(y_true).reshape(-1)
    logits = np.asarray(logits)
    y_pred = np.argmax(logits, axis=-1).reshape(-1)

    cm = confusion_matrix(y_true, y_pred, labels=labels_sorted)

    # Per-label row-wise accuracy == recall from CM
    per_label_acc = {}
    for row_i, lab_id in enumerate(labels_sorted):
        denom = cm[row_i, :].sum()
        per_label_acc[ID2LABEL[lab_id]] = float(cm[row_i, row_i] / denom) if denom > 0 else float("nan")

    report_dict = classification_report(
        y_true,
        y_pred,
        labels=labels_sorted,
        target_names=label_names,
        digits=4,
        output_dict=True,
        zero_division=0,
    )

    # Derived summary metrics (consistent across splits)
    derived = {
        "accuracy": float(report_dict.get("accuracy", float("nan"))),
        "macro_precision": float(report_dict.get("macro avg", {}).get("precision", float("nan"))),
        "macro_recall": float(report_dict.get("macro avg", {}).get("recall", float("nan"))),
        "macro_f1": float(report_dict.get("macro avg", {}).get("f1-score", float("nan"))),
        "weighted_f1": float(report_dict.get("weighted avg", {}).get("f1-score", float("nan"))),
    }

    # Store metrics with a consistent prefix for plotting helpers
    overall_metrics = {}
    if metrics:
        overall_metrics.update(metrics)

    # Ensure we always have an "*accuracy" key for plotting (even for sub-splits)
    overall_metrics[f"final_{split_name}_accuracy"] = derived["accuracy"]
    overall_metrics[f"final_{split_name}_macro_f1"] = derived["macro_f1"]

    return {
        "split": split_name,
        "num_samples": int(len(y_true)),
        "overall_metrics": overall_metrics,
        "derived_metrics": derived,
        "per_label_accuracy_rowwise": per_label_acc,
        "confusion_matrix": {"labels": label_names, "matrix": cm.tolist()},
        "classification_report": report_dict,
    }

def _extract_overall_acc(metrics: dict, report_dict: dict):
    # Prefer trainer metric if present; fallback to classification_report accuracy.
    acc_key = next((k for k in metrics.keys() if k.endswith("accuracy")), None)
    if acc_key is not None and isinstance(metrics.get(acc_key, None), (int, float)):
        return float(metrics[acc_key])
    if "accuracy" in report_dict and isinstance(report_dict["accuracy"], (int, float)):
        return float(report_dict["accuracy"])
    return float("nan")

# ------------------------------
# Plotting (unchanged behavior, now used for each split)
# ------------------------------

def plot_accuracy_f1_recall(split_result: dict, out_dir: str):
    """
    Figure 1:
      - Per-class Recall (row-wise accuracy) + Per-class F1 (grouped bars)
      - Overall accuracy (horizontal line)
      - Macro Recall / Macro F1 (text)
    """
    labels = split_result["confusion_matrix"]["labels"]
    report = split_result["classification_report"]
    metrics = split_result["overall_metrics"]

    recalls = []
    f1s = []
    supports = []
    for lab in labels:
        r = split_result["per_label_accuracy_rowwise"].get(lab, float("nan"))
        recalls.append(r)

        if lab in report:
            f1s.append(float(report[lab].get("f1-score", 0.0)))
            supports.append(int(report[lab].get("support", 0)))
        else:
            f1s.append(0.0)
            supports.append(0)

    recalls_plot = [0.0 if (r is None or not np.isfinite(r)) else float(r) for r in recalls]

    overall_acc = _extract_overall_acc(metrics, report)
    macro_recall = float(report.get("macro avg", {}).get("recall", float("nan")))
    macro_f1 = float(report.get("macro avg", {}).get("f1-score", float("nan")))

    x = np.arange(len(labels))
    width = 0.40

    plt.figure(figsize=(max(10, 0.7 * len(labels)), 6))
    plt.bar(x - width/2, recalls_plot, width, label="Per-class Recall (row-wise acc)")
    plt.bar(x + width/2, f1s, width, label="Per-class F1")

    if np.isfinite(overall_acc):
        plt.axhline(overall_acc, linestyle="--", linewidth=2, label=f"Overall Accuracy = {overall_acc:.4f}")

    xticks = [f"{lab}\n(n={n})" for lab, n in zip(labels, supports)]
    plt.xticks(x, xticks, rotation=45, ha="right")
    plt.ylim(0, 1.05)
    plt.ylabel("Score")
    plt.title(f"[{split_result['split']}] Per-class Recall/F1 + Overall Accuracy")

    text_lines = []
    if np.isfinite(macro_recall):
        text_lines.append(f"Macro Recall: {macro_recall:.4f}")
    if np.isfinite(macro_f1):
        text_lines.append(f"Macro F1: {macro_f1:.4f}")
    if np.isfinite(overall_acc):
        text_lines.append(f"Overall Acc: {overall_acc:.4f}")
    if text_lines:
        plt.gca().text(
            1.01, 0.5,
            "\n".join(text_lines),
            transform=plt.gca().transAxes,
            va="center",
            fontsize=11,
            bbox=dict(boxstyle="round", alpha=0.2),
        )

    plt.legend()
    plt.tight_layout()

    os.makedirs(out_dir, exist_ok=True)
    fig_path = os.path.join(out_dir, f"final_{split_result['split']}_metrics.png")
    plt.savefig(fig_path, dpi=200)
    plt.show()
    print(f"Saved metrics figure to: {fig_path}")

def plot_confusion_matrix(split_result: dict, out_dir: str):
    """
    Figure 2:
      - Confusion matrix with row-normalized heatmap
      - Annotate each cell with: count + normalized value
    """
    labels = split_result["confusion_matrix"]["labels"]
    cm = np.array(split_result["confusion_matrix"]["matrix"], dtype=np.int64)

    row_sums = cm.sum(axis=1, keepdims=True)
    with np.errstate(divide="ignore", invalid="ignore"):
        cm_norm = np.divide(cm, row_sums, where=(row_sums != 0))
        cm_norm = np.nan_to_num(cm_norm)

    plt.figure(figsize=(max(8, 0.6 * len(labels)), max(6, 0.6 * len(labels))))
    im = plt.imshow(cm_norm)  # default colormap is fine
    plt.colorbar(im, fraction=0.046, pad=0.04)

    plt.xticks(np.arange(len(labels)), labels, rotation=45, ha="right")
    plt.yticks(np.arange(len(labels)), labels)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"[{split_result['split']}] Confusion Matrix (row-normalized colors)")

    for i in range(len(labels)):
        for j in range(len(labels)):
            plt.text(
                j, i,
                f"{cm[i, j]}\n{cm_norm[i, j]:.2f}",
                ha="center", va="center",
                fontsize=9
            )

    plt.tight_layout()

    os.makedirs(out_dir, exist_ok=True)
    fig_path = os.path.join(out_dir, f"final_{split_result['split']}_confusion_matrix.png")
    plt.savefig(fig_path, dpi=200)
    plt.show()
    print(f"Saved confusion matrix figure to: {fig_path}")

# %% [markdown]
# ## 8. Gradient Importance Helpers

# %%
# ============================================================
# BLOCK 1: Gradient importance analysis — batched, use_true_label=True
# ============================================================
# Key design decisions:
#   - GRAD_BATCH_SIZE = 8 (lower this if TPU memory is tight)
#   - use_true_label=True : attribute toward ground-truth class
#   - Batching: transformer Jacobian is block-diagonal across the batch, so
#     d(Σ_b logit[b,target[b]]) / d(embeds[b]) == d(logit[b,target[b]]) / d(embeds[b])
#   - torch_xla.sync() once per batch → ~batch_size× speedup vs per-sample
#   - output_hidden_states=False + explicit del of XLA tensors → no HBM leak
#   - model.zero_grad(set_to_none=True) AFTER backward frees ~3.4 GB param grads
# ============================================================

# ── Batch size ────────────────────────────────────────────────────────────────
GRAD_BATCH_SIZE = globals().get('GRAD_BATCH_SIZE', 8)
GRAD_TOPK = globals().get('GRAD_TOPK', 100)


# ---------- Token cleaning ----------
def _clean_token(tok_str: str) -> str:
    return tok_str.replace("▁", " ").replace("Ġ", " ").strip()


# ---------- Batched gradient importance (memory-safe) ----------
def compute_gradient_importance_batch(model, tokenizer, examples, device,
                                       topk=None, use_true_label=True):
    """
    Compute gradient×input saliency for a batch of examples in ONE forward+backward.

    Memory contract  (revised — aggressively frees CPU + XLA memory)
    ───────────────
    1. Raw embedding tensor (_raw) is separated and deleted before forward pass.
    2. After backward: model.zero_grad(set_to_none=True) frees ~3.4 GB of
       parameter gradients that backward() allocated.
    3. Saliency is computed in a single fused expression (no extra named tensors).
    4. embeds.grad is set to None, then embeds is deleted.
    5. torch_xla.sync() + gc.collect() at the end to force XLA buffer reclamation.
    """
    if topk is None:
        topk = globals().get('GRAD_TOPK', 100)

    B = len(examples)

    input_ids_list = [ex["input_ids"]     for ex in examples]
    attn_mask_list = [ex["attention_mask"] for ex in examples]
    inp_mask_list  = [ex["inp_token_mask"] for ex in examples]
    true_labels    = [int(ex["labels"]) if "labels" in ex else None for ex in examples]

    # ── Build XLA tensors ─────────────────────────────────────────────────────
    input_ids_t = torch.tensor(input_ids_list, dtype=torch.long).to(device)
    attn_mask_t = torch.tensor(attn_mask_list, dtype=torch.long).to(device)

    # Embedding lookup — separate raw tensor so we can free it immediately
    _raw = model.get_input_embeddings()(input_ids_t)
    del input_ids_t                                    # ← free: not needed after lookup

    embeds = _raw.detach().clone().requires_grad_(True)  # [B, L, H]
    del _raw                                           # ← free autograd-graph-carrying tensor

    # ── Forward pass ─────────────────────────────────────────────────────────
    out = model(
        inputs_embeds=embeds,
        attention_mask=attn_mask_t,
        output_attentions=False,
        output_hidden_states=False,
        return_dict=True,
    )
    del attn_mask_t

    logits = out.logits
    del out

    pred_classes = torch.argmax(logits, dim=-1).cpu().tolist()

    # ── Determine target class per sample ─────────────────────────────────────
    target_classes = []
    for b in range(B):
        if use_true_label and true_labels[b] is not None:
            target_classes.append(true_labels[b])
        else:
            target_classes.append(pred_classes[b])

    # ── Backward pass ─────────────────────────────────────────────────────────
    target_logit_sum = sum(logits[b, target_classes[b]] for b in range(B))
    del logits

    model.zero_grad(set_to_none=True)                  # free leftover grads from prev batch
    target_logit_sum.backward()
    del target_logit_sum

    # ── Saliency → CPU numpy in one shot, then nuke all XLA refs ─────────────
    with torch.no_grad():
        grad_scores_batch = (embeds.grad * embeds).float().norm(dim=-1).cpu().numpy()

    # Free ~3.4 GB of parameter gradients that backward() just created
    model.zero_grad(set_to_none=True)

    # Break the grad reference, then delete the leaf tensor
    embeds.grad = None
    del embeds

    # Flush XLA lazy graph + force Python GC so the XLA allocator reclaims now
    torch_xla.sync()
    gc.collect()

    # ── Build per-sample results (pure Python/NumPy from here) ────────────────
    results = []
    for b in range(B):
        attn_mask_np       = np.array(attn_mask_list[b], dtype=np.int64)
        inp_mask_np        = np.array(inp_mask_list[b],  dtype=np.int64)
        grad_scores        = grad_scores_batch[b]
        grad_scores_masked = grad_scores.copy()
        grad_scores_masked[attn_mask_np == 0] = -np.inf
        grad_scores_masked[inp_mask_np  == 0] = -np.inf

        token_strs = tokenizer.convert_ids_to_tokens(input_ids_list[b])
        token_strs = [_clean_token(t) for t in token_strs]

        SPECIAL = {"", "[PAD]", "<pad>", "<s>", "</s>", "<unk>", "<|endoftext|>"}
        valid_indices = [
            i for i, t in enumerate(token_strs)
            if t not in SPECIAL and attn_mask_np[i] == 1 and inp_mask_np[i] == 1
        ]

        if not valid_indices:
            results.append(([], [], pred_classes[b], true_labels[b]))
            continue

        valid_scores = grad_scores_masked[valid_indices]
        top_k_local  = min(topk, len(valid_indices))
        top_k_idx    = np.argsort(-valid_scores)[:top_k_local]

        top_tokens = [token_strs[valid_indices[i]] for i in top_k_idx]
        top_scores = valid_scores[top_k_idx].tolist()
        results.append((top_tokens, top_scores, pred_classes[b], true_labels[b]))

    return results


# ---------- Main analysis loop (memory-safe) ----------
def run_gradient_analysis(model, tokenizer, tok, organ_keys,
                           samples_per_organ=None, device=None,
                           batch_size=None, topk=None, use_true_label=True):
    """
    Run batched gradient importance analysis on all organs.

    Memory strategy
    ───────────────
    - compute_gradient_importance_batch now handles sync + gc internally
    - Extra gc.collect() every GC_EVERY_N_BATCHES as safety net
    """
    GC_EVERY_N_BATCHES = 1    # gc every batch — critical for preventing RAM drift

    if device is None:
        device = torch_xla.device()
    if batch_size is None:
        batch_size = globals().get('GRAD_BATCH_SIZE', 8)
    if topk is None:
        topk = globals().get('GRAD_TOPK', 100)
    model.eval()

    organ_freq    = defaultdict(Counter)
    organ_scores  = defaultdict(Counter)
    global_freq   = Counter()
    global_scores = Counter()

    samples_processed = defaultdict(int)
    total_time        = 0.0

    for organ in organ_keys:
        if organ not in tok:
            print(f"[WARN] '{organ}' not found in tok, skipping.")
            continue

        organ_ds  = tok[organ]
        n_samples = len(organ_ds)
        if n_samples == 0:
            print(f"[WARN] '{organ}' dataset is empty, skipping.")
            continue

        n_to_process = n_samples if samples_per_organ is None else min(samples_per_organ, n_samples)
        print(f"[{organ.upper()}] Processing {n_to_process}/{n_samples} samples "
              f"(batch_size={batch_size}, use_true_label={use_true_label})...")

        batch_num = 0
        idx = 0
        while idx < n_to_process:
            batch_end = min(idx + batch_size, n_to_process)
            examples  = [organ_ds[i] for i in range(idx, batch_end)]
            t_start = time.perf_counter()

            batch_results = compute_gradient_importance_batch(
                model, tokenizer, examples, device,
                topk=topk, use_true_label=use_true_label,
            )
            # NOTE: torch_xla.sync() + gc.collect() already called inside
            # compute_gradient_importance_batch — no need to sync again here.
            del examples   # ← free raw Python dicts

            elapsed     = time.perf_counter() - t_start
            total_time += elapsed

            # Aggregate
            for top_tokens, top_scores, pred_class, true_label in batch_results:
                for tok_str, score in zip(top_tokens, top_scores):
                    organ_freq[organ][tok_str]   += 1
                    organ_scores[organ][tok_str] += score
                    global_freq[tok_str]          += 1
                    global_scores[tok_str]        += score
                samples_processed[organ] += 1
            del batch_results

            idx       += batch_size
            batch_num += 1

            # Extra safety-net GC (lightweight if nothing to collect)
            if batch_num % GC_EVERY_N_BATCHES == 0:
                gc.collect()

            # Progress log every 50 samples or at end
            if idx % 50 < batch_size or idx >= n_to_process:
                total_so_far   = sum(samples_processed.values())
                avg_per_sample = total_time / total_so_far if total_so_far > 0 else 0.0
                print(f"    [{organ}] {min(idx, n_to_process)}/{n_to_process} done, "
                      f"avg {avg_per_sample:.2f}s/sample")

        # End-of-organ cleanup
        torch_xla.sync()
        gc.collect()
        print(f"  -> [{organ.upper()}] Done. Running total time: {total_time:.2f}s")

    # ── Avg-per-sample normalization (fair cross-organ comparison) ────────────
    organ_scores_avg = {}
    for _organ, _tok_scores in organ_scores.items():
        _n = samples_processed.get(_organ, 1) or 1
        organ_scores_avg[_organ] = Counter({_t: _s / _n for _t, _s in _tok_scores.items()})

    _global_n = sum(samples_processed.values()) or 1
    global_scores_avg = Counter({_t: _s / _global_n for _t, _s in global_scores.items()})

    organ_freq_avg = {}
    for _organ, _tok_freq in organ_freq.items():
        _n = samples_processed.get(_organ, 1) or 1
        organ_freq_avg[_organ] = Counter({_t: _c / _n for _t, _c in _tok_freq.items()})
    global_freq_avg = Counter({_t: _c / _global_n for _t, _c in global_freq.items()})

    return {
        "organ_freq":        dict(organ_freq),
        "organ_scores":      dict(organ_scores),
        "organ_scores_avg":  organ_scores_avg,
        "global_freq":       global_freq,
        "global_scores":     global_scores,
        "global_scores_avg": global_scores_avg,
        "organ_freq_avg":    organ_freq_avg,
        "global_freq_avg":   global_freq_avg,
        "samples_processed": dict(samples_processed),
        "total_time":        total_time,
    }

def visualize_results(results, organ_keys, out_dir=None, top_n=None, bar_color=None, wordcloud_cmap=None, figsize=None):
    """Print and plot global gradient-importance summaries without recomputing gradients."""
    if top_n is None:
        top_n = globals().get('PLOT_TOP_N', 100)
    if bar_color is None:
        bar_color = globals().get('PLOT_BAR_COLOR', 'steelblue')
    if wordcloud_cmap is None:
        wordcloud_cmap = globals().get('PLOT_WORDCLOUD_CMAP', 'plasma')
    if figsize is None:
        figsize = globals().get('PLOT_FIGSIZE', (16, 20))
    global_freq = Counter(results.get('global_freq', {}))
    global_scores = Counter(results.get('global_scores', {}))
    global_freq_avg = Counter(results.get('global_freq_avg', {}))

    if out_dir:
        os.makedirs(out_dir, exist_ok=True)

    print('\n' + '=' * 60)
    print('VISUALIZATION RESULTS')
    print('=' * 60)
    print(f"Samples processed: {results.get('samples_processed', {})}")
    print(f"Total time: {results.get('total_time', 0.0):.2f}s")

    top_global_freq = global_freq.most_common(top_n)
    print(f'\n--- Top {top_n} tokens by frequency (all organs) ---')
    for tok_str, count in top_global_freq:
        print(f"  '{tok_str}': {count}")
    if top_global_freq:
        tokens = [t for t, _ in top_global_freq]
        counts = [c for _, c in top_global_freq]
        plt.figure(figsize=figsize)
        plt.barh(range(len(tokens)), counts[::-1], color=bar_color)
        plt.yticks(range(len(tokens)), tokens[::-1], fontsize=10)
        plt.xlabel(f'Frequency in Top-{top_n}')
        plt.title(f'[ALL ORGANS] Top {top_n} Tokens by Frequency')
        plt.tight_layout()
        if out_dir:
            plt.savefig(os.path.join(out_dir, 'freq_global.png'), dpi=150)
        plt.show()

    top_global_scores = global_scores.most_common(top_n)
    print(f'\n--- Top {top_n} tokens by total score (all organs) ---')
    for tok_str, score in top_global_scores:
        print(f"  '{tok_str}': {score:.4f}")
    if top_global_scores:
        tokens = [t for t, _ in top_global_scores]
        scores = [s for _, s in top_global_scores]
        plt.figure(figsize=figsize)
        plt.barh(range(len(tokens)), scores[::-1], color=bar_color)
        plt.yticks(range(len(tokens)), tokens[::-1])
        plt.xlabel('Total Gradient Score')
        plt.title(f'[ALL ORGANS] Top {top_n} Tokens by Total Score')
        plt.tight_layout()
        if out_dir:
            plt.savefig(os.path.join(out_dir, 'score_global.png'), dpi=150)
        plt.show()

    top_global_freq_avg = global_freq_avg.most_common(top_n)
    print(f'\n--- Top {top_n} tokens by average frequency (global) ---')
    for tok_str, frac in top_global_freq_avg:
        print(f"  '{tok_str}': {frac:.4f}")
    if top_global_freq_avg:
        tokens = [t for t, _ in top_global_freq_avg]
        fracs = [f for _, f in top_global_freq_avg]
        plt.figure(figsize=figsize)
        plt.barh(range(len(tokens)), fracs[::-1])
        plt.yticks(range(len(tokens)), tokens[::-1])
        plt.xlabel(f'Average frequency in Top-{top_n}')
        plt.title(f'[ALL ORGANS] Top {top_n} Tokens by Average Frequency')
        plt.tight_layout()
        if out_dir:
            plt.savefig(os.path.join(out_dir, 'avg_freq_global.png'), dpi=150)
        plt.show()

    print('\n--- Word cloud (all organs, by total score) ---')
    wc_dict = {t: max(s, 1e-6) for t, s in top_global_scores if s > 0}
    if len(wc_dict) >= 5:
        wc = WordCloud(width=800, height=600, background_color='white', max_words=top_n, colormap=wordcloud_cmap)
        wc.generate_from_frequencies(wc_dict)
        plt.figure(figsize=(16, 12))
        plt.imshow(wc, interpolation='bilinear')
        plt.axis('off')
        plt.title(f'[ALL ORGANS] Word Cloud (Top {top_n} by Score)')
        plt.tight_layout()
        if out_dir:
            plt.savefig(os.path.join(out_dir, 'wordcloud_global.png'), dpi=150)
        plt.show()

    print('\n' + '=' * 60)
    print('VISUALIZATION COMPLETE')
    if out_dir:
        print(f'Plots saved to: {out_dir}')
    print('=' * 60)
    return top_global_scores

def analyze_organ_specificity(results, organ_keys, topk=100, out_dir=None):
    """
    Identify tokens universally important vs. organ-exclusive.
    Uses avg-per-sample scores for fair cross-organ comparison.
    """
    organ_scores_src = results.get("organ_scores_avg") or results.get("organ_scores", {})

    organ_topk_sets = {}
    for organ in organ_keys:
        if organ not in organ_scores_src:
            continue
        top_tokens = [t for t, _ in Counter(organ_scores_src[organ]).most_common(topk)]
        organ_topk_sets[organ] = set(top_tokens)

    if not organ_topk_sets:
        print("[WARN] No organ data found in results.")
        return {}

    token_organ_count = Counter()
    for organ, tok_set in organ_topk_sets.items():
        for t in tok_set:
            token_organ_count[t] += 1

    n_organs  = len(organ_topk_sets)
    universal = [t for t, c in token_organ_count.most_common() if c == n_organs]

    exclusive = {organ: [] for organ in organ_keys}
    for t, c in token_organ_count.items():
        if c == 1:
            for organ, tok_set in organ_topk_sets.items():
                if t in tok_set:
                    exclusive[organ].append(t)
                    break

    print("\n" + "="*60)
    print("ORGAN SPECIFICITY ANALYSIS")
    print("="*60)
    print(f"\nTokens in top-{topk} for ALL {n_organs} organs ({len(universal)} tokens):")
    for t in universal[:30]:
        print(f"  '{t}'")
    print("\nOrgan-exclusive tokens (unique to each organ's top-k):")
    for organ in organ_keys:
        excl = exclusive.get(organ, [])
        print(f"  [{organ.upper()}] {len(excl)} exclusive: {excl[:20]}")

    # Frequency-based specificity
    _ofsrc = results.get("organ_freq_avg") or results.get("organ_freq", {})
    _otfs  = {o: set(t for t, _ in Counter(_ofsrc.get(o, {})).most_common(topk)) for o in organ_keys}
    _tfc   = Counter()
    for _s in _otfs.values():
        for _t in _s:
            _tfc[_t] += 1
    _no = len([o for o in organ_keys if _otfs.get(o)])
    _uf = [t for t, c in _tfc.most_common() if c == _no]
    _ef = {o: [t for t, c in _tfc.items() if c == 1 and t in _otfs.get(o, set())] for o in organ_keys}
    print("\n--- Frequency-based specificity ---")
    print(f"Universal by freq ({len(_uf)} tokens): {_uf[:30]}")
    print("Exclusive by freq:")
    for o in organ_keys:
        print(f"  [{o.upper()}] {len(_ef.get(o,[]))}: {_ef.get(o,[])[:20]}")

    # Pairwise overlap heatmap
    organ_list = [o for o in organ_keys if o in organ_topk_sets]
    n = len(organ_list)
    if n > 1:
        overlap_matrix = np.zeros((n, n), dtype=int)
        for i in range(n):
            for j in range(n):
                overlap_matrix[i, j] = len(organ_topk_sets[organ_list[i]] & organ_topk_sets[organ_list[j]])

        fig, ax = plt.subplots(figsize=(10, 8))
        im = ax.imshow(overlap_matrix, cmap="YlOrRd")
        ax.set_xticks(range(n)); ax.set_yticks(range(n))
        ax.set_xticklabels(organ_list, rotation=45, ha="right")
        ax.set_yticklabels(organ_list)
        plt.colorbar(im, ax=ax, label=f"# shared tokens in top-{topk}")
        for i in range(n):
            for j in range(n):
                ax.text(j, i, str(overlap_matrix[i, j]), ha="center", va="center", fontsize=10)
        ax.set_title(f"Organ pairwise token overlap (top-{topk} by avg gradient score)")
        plt.tight_layout()
        if out_dir:
            os.makedirs(out_dir, exist_ok=True)
            fig_path = os.path.join(out_dir, "organ_token_overlap.png")
            plt.savefig(fig_path, dpi=150)
            print(f"Saved: {fig_path}")
        plt.show()

    return {
        "universal_tokens":  universal,
        "exclusive_tokens":  exclusive,
        "token_organ_count": dict(token_organ_count),
        "organ_topk_sets":   {k: list(v) for k, v in organ_topk_sets.items()},
    }

# %% [markdown]
# ## 9. Run Full Analysis

# %%
required = ['tok', 'model', 'tokenizer', 'run_gradient_analysis']
missing = [name for name in required if name not in globals()]
if missing:
    raise RuntimeError(f'Missing variables: {missing}. Run setup through gradient utility cells first.')

os.makedirs(RESULTS_DIR, exist_ok=True)

print('=' * 60)
limit_msg = 'all samples' if SAMPLES_PER_ORGAN is None else f'{SAMPLES_PER_ORGAN} samples per organ'
print(f'GRADIENT RUN: {limit_msg}, batch_size={GRAD_BATCH_SIZE}, topk={GRAD_TOPK}, use_true_label={USE_TRUE_LABEL}')
print('=' * 60)

print('\nDataset sizes (all 11 parts per organ):')
total_samples = 0
for organ in ORGAN_KEYS:
    if organ in tok:
        n = len(tok[organ])
        n_run = n if SAMPLES_PER_ORGAN is None else min(SAMPLES_PER_ORGAN, n)
        print(f'  {organ}: {n_run}/{n}')
        total_samples += n_run
print(f'  TOTAL TO RUN: {total_samples}')

print('\nStarting gradient analysis...')
full_results = run_gradient_analysis(
    model,
    tokenizer,
    tok,
    ORGAN_KEYS,
    samples_per_organ=SAMPLES_PER_ORGAN,
    device=torch_xla.device(),
    batch_size=GRAD_BATCH_SIZE,
    topk=GRAD_TOPK,
    use_true_label=USE_TRUE_LABEL,
)

print(f"\nGradient analysis done. Total time: {full_results['total_time']:.1f}s")
print(f"Samples processed: {full_results['samples_processed']}")

with open(RESULTS_PKL, 'wb') as f:
    pickle.dump(full_results, f)

results_to_save = {
    'organ_freq': {k: dict(v) for k, v in full_results['organ_freq'].items()},
    'organ_scores': {k: dict(v) for k, v in full_results['organ_scores'].items()},
    'organ_scores_avg': {k: dict(v) for k, v in full_results['organ_scores_avg'].items()},
    'global_freq': dict(full_results['global_freq']),
    'global_scores': dict(full_results['global_scores']),
    'global_scores_avg': dict(full_results['global_scores_avg']),
    'organ_freq_avg': {k: dict(v) for k, v in full_results.get('organ_freq_avg', {}).items()},
    'global_freq_avg': dict(full_results.get('global_freq_avg', {})),
    'samples_processed': full_results['samples_processed'],
    'total_time': full_results['total_time'],
    'settings': {
        'model_id': MODEL_ID,
        'max_length': MAX_LENGTH,
        'grad_topk': GRAD_TOPK,
        'grad_batch_size': GRAD_BATCH_SIZE,
        'samples_per_organ': SAMPLES_PER_ORGAN,
        'use_true_label': USE_TRUE_LABEL,
    },
}
with open(RESULTS_JSON, 'w') as f:
    json.dump(results_to_save, f, indent=2)

print(f'Pickle results saved before plotting: {RESULTS_PKL}')
print(f'JSON summary saved before plotting: {RESULTS_JSON}')
# Out:
# ============================================================
# GRADIENT RUN: all samples, batch_size=8, topk=100, use_true_label=True
# ============================================================
#
# Dataset sizes (all 11 parts per organ):
#   bladder: 7615/7615
#   brain: 19154/19154
#   bone: 25169/25169
#   limb: 17396/17396
#   kidney: 7262/7262
#   liver: 3859/3859
#   lung: 8992/8992
#   heart: 4792/4792
#   TOTAL TO RUN: 94239
#
# Starting gradient analysis...
# [BLADDER] Processing 7615/7615 samples (batch_size=8, use_true_label=True)...
# [transformers] Qwen3ForSequenceClassification will not detect padding tokens in `inputs_embeds`. Results may be unexpected if using padding tokens in conjunction with `inputs_embeds.`
#     [bladder] 56/7615 done, avg 1.65s/sample
#     [bladder] 104/7615 done, avg 0.93s/sample
#     [bladder] 152/7615 done, avg 0.67s/sample
#     [bladder] 200/7615 done, avg 0.83s/sample
#     [bladder] 256/7615 done, avg 0.67s/sample
#     [bladder] 304/7615 done, avg 0.58s/sample
#     [bladder] 352/7615 done, avg 0.64s/sample
#     [bladder] 400/7615 done, avg 0.57s/sample
#     [bladder] 456/7615 done, avg 0.58s/sample
#     [bladder] 504/7615 done, avg 0.59s/sample
#     [bladder] 552/7615 done, avg 0.66s/sample
#     [bladder] 600/7615 done, avg 0.61s/sample
#     [bladder] 656/7615 done, avg 0.57s/sample
#     [bladder] 704/7615 done, avg 0.58s/sample
#     [bladder] 752/7615 done, avg 0.55s/sample
#     [bladder] 800/7615 done, avg 0.52s/sample
#     [bladder] 856/7615 done, avg 0.49s/sample
#     [bladder] 904/7615 done, avg 0.50s/sample
#     [bladder] 952/7615 done, avg 0.48s/sample
#     [bladder] 1000/7615 done, avg 0.46s/sample
#     [bladder] 1056/7615 done, avg 0.44s/sample
#     [bladder] 1104/7615 done, avg 0.43s/sample
#     [bladder] 1152/7615 done, avg 0.42s/sample
#     [bladder] 1200/7615 done, avg 0.40s/sample
#     [bladder] 1256/7615 done, avg 0.41s/sample
#     [bladder] 1304/7615 done, avg 0.40s/sample
#     [bladder] 1352/7615 done, avg 0.39s/sample
#     [bladder] 1400/7615 done, avg 0.40s/sample
#     [bladder] 1456/7615 done, avg 0.39s/sample
#     [bladder] 1504/7615 done, avg 0.38s/sample
#     [bladder] 1552/7615 done, avg 0.37s/sample
#     [bladder] 1600/7615 done, avg 0.38s/sample
#     [bladder] 1656/7615 done, avg 0.37s/sample
#     [bladder] 1704/7615 done, avg 0.37s/sample
#     [bladder] 1752/7615 done, avg 0.36s/sample
#     [bladder] 1800/7615 done, avg 0.35s/sample
#     [bladder] 1856/7615 done, avg 0.36s/sample
#     [bladder] 1904/7615 done, avg 0.35s/sample
#     [bladder] 1952/7615 done, avg 0.36s/sample
#     [bladder] 2000/7615 done, avg 0.36s/sample
#     [bladder] 2056/7615 done, avg 0.35s/sample
#     [bladder] 2104/7615 done, avg 0.36s/sample
#     [bladder] 2152/7615 done, avg 0.35s/sample
#     [bladder] 2200/7615 done, avg 0.35s/sample
#     [bladder] 2256/7615 done, avg 0.35s/sample
#     [bladder] 2304/7615 done, avg 0.35s/sample
#     [bladder] 2352/7615 done, avg 0.34s/sample
#     [bladder] 2400/7615 done, avg 0.34s/sample
#     [bladder] 2456/7615 done, avg 0.33s/sample
#     [bladder] 2504/7615 done, avg 0.33s/sample
#     [bladder] 2552/7615 done, avg 0.33s/sample
#     [bladder] 2600/7615 done, avg 0.33s/sample
#     [bladder] 2656/7615 done, avg 0.35s/sample
#     [bladder] 2704/7615 done, avg 0.34s/sample
#     [bladder] 2752/7615 done, avg 0.34s/sample
#     [bladder] 2800/7615 done, avg 0.35s/sample
#     [bladder] 2856/7615 done, avg 0.34s/sample
#     [bladder] 2904/7615 done, avg 0.34s/sample
#     [bladder] 2952/7615 done, avg 0.33s/sample
#     [bladder] 3000/7615 done, avg 0.33s/sample
#     [bladder] 3056/7615 done, avg 0.33s/sample
#     [bladder] 3104/7615 done, avg 0.32s/sample
#     [bladder] 3152/7615 done, avg 0.32s/sample
#     [bladder] 3200/7615 done, avg 0.31s/sample
#     [bladder] 3256/7615 done, avg 0.32s/sample
#     [bladder] 3304/7615 done, avg 0.33s/sample
#     [bladder] 3352/7615 done, avg 0.32s/sample
#     [bladder] 3400/7615 done, avg 0.32s/sample
#     [bladder] 3456/7615 done, avg 0.32s/sample
#     [bladder] 3504/7615 done, avg 0.31s/sample
#     [bladder] 3552/7615 done, avg 0.31s/sample
#     [bladder] 3600/7615 done, avg 0.31s/sample
#     [bladder] 3656/7615 done, avg 0.30s/sample
#     [bladder] 3704/7615 done, avg 0.30s/sample
#     [bladder] 3752/7615 done, avg 0.30s/sample
#     [bladder] 3800/7615 done, avg 0.30s/sample
#     [bladder] 3856/7615 done, avg 0.29s/sample
#     [bladder] 3904/7615 done, avg 0.29s/sample
#     [bladder] 3952/7615 done, avg 0.29s/sample
#     [bladder] 4000/7615 done, avg 0.29s/sample
#     [bladder] 4056/7615 done, avg 0.28s/sample
#     [bladder] 4104/7615 done, avg 0.28s/sample
#     [bladder] 4152/7615 done, avg 0.28s/sample
#     [bladder] 4200/7615 done, avg 0.28s/sample
#     [bladder] 4256/7615 done, avg 0.28s/sample
#     [bladder] 4304/7615 done, avg 0.27s/sample
#     [bladder] 4352/7615 done, avg 0.27s/sample
#     [bladder] 4400/7615 done, avg 0.27s/sample
#     [bladder] 4456/7615 done, avg 0.27s/sample
#     [bladder] 4504/7615 done, avg 0.27s/sample
#     [bladder] 4552/7615 done, avg 0.26s/sample
#     [bladder] 4600/7615 done, avg 0.26s/sample
#     [bladder] 4656/7615 done, avg 0.26s/sample
#     [bladder] 4704/7615 done, avg 0.26s/sample
#     [bladder] 4752/7615 done, avg 0.26s/sample
#     [bladder] 4800/7615 done, avg 0.26s/sample
#     [bladder] 4856/7615 done, avg 0.25s/sample
#     [bladder] 4904/7615 done, avg 0.25s/sample
#     [bladder] 4952/7615 done, avg 0.25s/sample
#     [bladder] 5000/7615 done, avg 0.25s/sample
#     [bladder] 5056/7615 done, avg 0.25s/sample
#     [bladder] 5104/7615 done, avg 0.25s/sample
#     [bladder] 5152/7615 done, avg 0.25s/sample
#     [bladder] 5200/7615 done, avg 0.25s/sample
#     [bladder] 5256/7615 done, avg 0.25s/sample
#     [bladder] 5304/7615 done, avg 0.25s/sample
#     [bladder] 5352/7615 done, avg 0.25s/sample
#     [bladder] 5400/7615 done, avg 0.25s/sample
#     [bladder] 5456/7615 done, avg 0.25s/sample
#     [bladder] 5504/7615 done, avg 0.25s/sample
#     [bladder] 5552/7615 done, avg 0.24s/sample
#     [bladder] 5600/7615 done, avg 0.24s/sample
#     [bladder] 5656/7615 done, avg 0.24s/sample
#     [bladder] 5704/7615 done, avg 0.24s/sample
#     [bladder] 5752/7615 done, avg 0.24s/sample
#     [bladder] 5800/7615 done, avg 0.24s/sample
#     [bladder] 5856/7615 done, avg 0.24s/sample
#     [bladder] 5904/7615 done, avg 0.24s/sample
#     [bladder] 5952/7615 done, avg 0.24s/sample
#     [bladder] 6000/7615 done, avg 0.23s/sample
#     [bladder] 6056/7615 done, avg 0.23s/sample
#     [bladder] 6104/7615 done, avg 0.23s/sample
#     [bladder] 6152/7615 done, avg 0.23s/sample
#     [bladder] 6200/7615 done, avg 0.23s/sample
#     [bladder] 6256/7615 done, avg 0.23s/sample
#     [bladder] 6304/7615 done, avg 0.23s/sample
#     [bladder] 6352/7615 done, avg 0.23s/sample
#     [bladder] 6400/7615 done, avg 0.23s/sample
#     [bladder] 6456/7615 done, avg 0.22s/sample
#     [bladder] 6504/7615 done, avg 0.22s/sample
#     [bladder] 6552/7615 done, avg 0.22s/sample
#     [bladder] 6600/7615 done, avg 0.22s/sample
#     [bladder] 6656/7615 done, avg 0.22s/sample
#     [bladder] 6704/7615 done, avg 0.22s/sample
#     [bladder] 6752/7615 done, avg 0.22s/sample
#     [bladder] 6800/7615 done, avg 0.22s/sample
#     [bladder] 6856/7615 done, avg 0.22s/sample
#     [bladder] 6904/7615 done, avg 0.22s/sample
#     [bladder] 6952/7615 done, avg 0.22s/sample
#     [bladder] 7000/7615 done, avg 0.22s/sample
#     [bladder] 7056/7615 done, avg 0.22s/sample
#     [bladder] 7104/7615 done, avg 0.22s/sample
#     [bladder] 7152/7615 done, avg 0.22s/sample
#     [bladder] 7200/7615 done, avg 0.22s/sample
#     [bladder] 7256/7615 done, avg 0.21s/sample
#     [bladder] 7304/7615 done, avg 0.21s/sample
#     [bladder] 7352/7615 done, avg 0.21s/sample
#     [bladder] 7400/7615 done, avg 0.21s/sample
#     [bladder] 7456/7615 done, avg 0.21s/sample
#     [bladder] 7504/7615 done, avg 0.21s/sample
#     [bladder] 7552/7615 done, avg 0.21s/sample
#     [bladder] 7600/7615 done, avg 0.21s/sample
#     [bladder] 7615/7615 done, avg 0.22s/sample
#   -> [BLADDER] Done. Running total time: 1637.54s
# [BRAIN] Processing 19154/19154 samples (batch_size=8, use_true_label=True)...
#     [brain] 56/19154 done, avg 0.22s/sample
#     [brain] 104/19154 done, avg 0.22s/sample
#     [brain] 152/19154 done, avg 0.22s/sample
#     [brain] 200/19154 done, avg 0.22s/sample
#     [brain] 256/19154 done, avg 0.22s/sample
#     [brain] 304/19154 done, avg 0.21s/sample
#     [brain] 352/19154 done, avg 0.21s/sample
#     [brain] 400/19154 done, avg 0.21s/sample
#     [brain] 456/19154 done, avg 0.22s/sample
#     [brain] 504/19154 done, avg 0.22s/sample
#     [brain] 552/19154 done, avg 0.21s/sample
#     [brain] 600/19154 done, avg 0.21s/sample
#     [brain] 656/19154 done, avg 0.21s/sample
#     [brain] 704/19154 done, avg 0.21s/sample
#     [brain] 752/19154 done, avg 0.21s/sample
#     [brain] 800/19154 done, avg 0.21s/sample
#     [brain] 856/19154 done, avg 0.21s/sample
#     [brain] 904/19154 done, avg 0.21s/sample
#     [brain] 952/19154 done, avg 0.21s/sample
#     [brain] 1000/19154 done, avg 0.21s/sample
#     [brain] 1056/19154 done, avg 0.21s/sample
#     [brain] 1104/19154 done, avg 0.21s/sample
#     [brain] 1152/19154 done, avg 0.21s/sample
#     [brain] 1200/19154 done, avg 0.21s/sample
#     [brain] 1256/19154 done, avg 0.21s/sample
#     [brain] 1304/19154 done, avg 0.21s/sample
#     [brain] 1352/19154 done, avg 0.21s/sample
#     [brain] 1400/19154 done, avg 0.21s/sample
#     [brain] 1456/19154 done, avg 0.21s/sample
#     [brain] 1504/19154 done, avg 0.22s/sample
#     [brain] 1552/19154 done, avg 0.21s/sample
#     [brain] 1600/19154 done, avg 0.21s/sample
#     [brain] 1656/19154 done, avg 0.21s/sample
#     [brain] 1704/19154 done, avg 0.21s/sample
#     [brain] 1752/19154 done, avg 0.22s/sample
#     [brain] 1800/19154 done, avg 0.21s/sample
#     [brain] 1856/19154 done, avg 0.21s/sample
#     [brain] 1904/19154 done, avg 0.21s/sample
#     [brain] 1952/19154 done, avg 0.21s/sample
#     [brain] 2000/19154 done, avg 0.21s/sample
#     [brain] 2056/19154 done, avg 0.21s/sample
#     [brain] 2104/19154 done, avg 0.21s/sample
#     [brain] 2152/19154 done, avg 0.21s/sample
#     [brain] 2200/19154 done, avg 0.21s/sample
#     [brain] 2256/19154 done, avg 0.21s/sample
#     [brain] 2304/19154 done, avg 0.21s/sample
#     [brain] 2352/19154 done, avg 0.21s/sample
#     [brain] 2400/19154 done, avg 0.21s/sample
#     [brain] 2456/19154 done, avg 0.21s/sample
#     [brain] 2504/19154 done, avg 0.21s/sample
#     [brain] 2552/19154 done, avg 0.21s/sample
#     [brain] 2600/19154 done, avg 0.21s/sample
#     [brain] 2656/19154 done, avg 0.21s/sample
#     [brain] 2704/19154 done, avg 0.21s/sample
#     [brain] 2752/19154 done, avg 0.21s/sample
#     [brain] 2800/19154 done, avg 0.21s/sample
#     [brain] 2856/19154 done, avg 0.21s/sample
#     [brain] 2904/19154 done, avg 0.21s/sample
#     [brain] 2952/19154 done, avg 0.21s/sample
#     [brain] 3000/19154 done, avg 0.21s/sample
#     [brain] 3056/19154 done, avg 0.21s/sample
#     [brain] 3104/19154 done, avg 0.21s/sample
#     [brain] 3152/19154 done, avg 0.21s/sample
#     [brain] 3200/19154 done, avg 0.21s/sample
#     [brain] 3256/19154 done, avg 0.21s/sample
#     [brain] 3304/19154 done, avg 0.21s/sample
#     [brain] 3352/19154 done, avg 0.21s/sample
#     [brain] 3400/19154 done, avg 0.21s/sample
#     [brain] 3456/19154 done, avg 0.21s/sample
#     [brain] 3504/19154 done, avg 0.21s/sample
#     [brain] 3552/19154 done, avg 0.21s/sample
#     [brain] 3600/19154 done, avg 0.21s/sample
#     [brain] 3656/19154 done, avg 0.21s/sample
#     [brain] 3704/19154 done, avg 0.21s/sample
#     [brain] 3752/19154 done, avg 0.21s/sample
#     [brain] 3800/19154 done, avg 0.21s/sample
#     [brain] 3856/19154 done, avg 0.21s/sample
#     [brain] 3904/19154 done, avg 0.21s/sample
#     [brain] 3952/19154 done, avg 0.21s/sample
#     [brain] 4000/19154 done, avg 0.20s/sample
#     [brain] 4056/19154 done, avg 0.20s/sample
#     [brain] 4104/19154 done, avg 0.20s/sample
#     [brain] 4152/19154 done, avg 0.20s/sample
#     [brain] 4200/19154 done, avg 0.20s/sample
#     [brain] 4256/19154 done, avg 0.20s/sample
#     [brain] 4304/19154 done, avg 0.20s/sample
#     [brain] 4352/19154 done, avg 0.20s/sample
#     [brain] 4400/19154 done, avg 0.20s/sample
#     [brain] 4456/19154 done, avg 0.20s/sample
#     [brain] 4504/19154 done, avg 0.20s/sample
#     [brain] 4552/19154 done, avg 0.20s/sample
#     [brain] 4600/19154 done, avg 0.20s/sample
#     [brain] 4656/19154 done, avg 0.20s/sample
#     [brain] 4704/19154 done, avg 0.20s/sample
#     [brain] 4752/19154 done, avg 0.20s/sample
#     [brain] 4800/19154 done, avg 0.20s/sample
#     [brain] 4856/19154 done, avg 0.20s/sample
#     [brain] 4904/19154 done, avg 0.20s/sample
#     [brain] 4952/19154 done, avg 0.20s/sample
#     [brain] 5000/19154 done, avg 0.20s/sample
#     [brain] 5056/19154 done, avg 0.20s/sample
#     [brain] 5104/19154 done, avg 0.20s/sample
#     [brain] 5152/19154 done, avg 0.20s/sample
#     [brain] 5200/19154 done, avg 0.20s/sample
#     [brain] 5256/19154 done, avg 0.20s/sample
#     [brain] 5304/19154 done, avg 0.20s/sample
#     [brain] 5352/19154 done, avg 0.20s/sample
#     [brain] 5400/19154 done, avg 0.20s/sample
#     [brain] 5456/19154 done, avg 0.20s/sample
#     [brain] 5504/19154 done, avg 0.20s/sample
#     [brain] 5552/19154 done, avg 0.20s/sample
#     [brain] 5600/19154 done, avg 0.20s/sample
#     [brain] 5656/19154 done, avg 0.20s/sample
#     [brain] 5704/19154 done, avg 0.20s/sample
#     [brain] 5752/19154 done, avg 0.20s/sample
#     [brain] 5800/19154 done, avg 0.20s/sample
#     [brain] 5856/19154 done, avg 0.20s/sample
#     [brain] 5904/19154 done, avg 0.20s/sample
#     [brain] 5952/19154 done, avg 0.20s/sample
#     [brain] 6000/19154 done, avg 0.20s/sample
#     [brain] 6056/19154 done, avg 0.20s/sample
#     [brain] 6104/19154 done, avg 0.20s/sample
#     [brain] 6152/19154 done, avg 0.20s/sample
#     [brain] 6200/19154 done, avg 0.20s/sample
#     [brain] 6256/19154 done, avg 0.20s/sample
#     [brain] 6304/19154 done, avg 0.20s/sample
#     [brain] 6352/19154 done, avg 0.19s/sample
#     [brain] 6400/19154 done, avg 0.19s/sample
#     [brain] 6456/19154 done, avg 0.19s/sample
#     [brain] 6504/19154 done, avg 0.19s/sample
#     [brain] 6552/19154 done, avg 0.19s/sample
#     [brain] 6600/19154 done, avg 0.19s/sample
#     [brain] 6656/19154 done, avg 0.19s/sample
#     [brain] 6704/19154 done, avg 0.19s/sample
#     [brain] 6752/19154 done, avg 0.19s/sample
#     [brain] 6800/19154 done, avg 0.19s/sample
#     [brain] 6856/19154 done, avg 0.19s/sample
#     [brain] 6904/19154 done, avg 0.19s/sample
#     [brain] 6952/19154 done, avg 0.19s/sample
#     [brain] 7000/19154 done, avg 0.19s/sample
#     [brain] 7056/19154 done, avg 0.19s/sample
#     [brain] 7104/19154 done, avg 0.19s/sample
#     [brain] 7152/19154 done, avg 0.19s/sample
#     [brain] 7200/19154 done, avg 0.19s/sample
#     [brain] 7256/19154 done, avg 0.19s/sample
#     [brain] 7304/19154 done, avg 0.19s/sample
#     [brain] 7352/19154 done, avg 0.19s/sample
#     [brain] 7400/19154 done, avg 0.19s/sample
#     [brain] 7456/19154 done, avg 0.19s/sample
#     [brain] 7504/19154 done, avg 0.19s/sample
#     [brain] 7552/19154 done, avg 0.19s/sample
#     [brain] 7600/19154 done, avg 0.19s/sample
#     [brain] 7656/19154 done, avg 0.19s/sample
#     [brain] 7704/19154 done, avg 0.19s/sample
#     [brain] 7752/19154 done, avg 0.19s/sample
#     [brain] 7800/19154 done, avg 0.19s/sample
#     [brain] 7856/19154 done, avg 0.19s/sample
#     [brain] 7904/19154 done, avg 0.19s/sample
#     [brain] 7952/19154 done, avg 0.19s/sample
#     [brain] 8000/19154 done, avg 0.19s/sample
#     [brain] 8056/19154 done, avg 0.19s/sample
#     [brain] 8104/19154 done, avg 0.19s/sample
#     [brain] 8152/19154 done, avg 0.19s/sample
#     [brain] 8200/19154 done, avg 0.19s/sample
#     [brain] 8256/19154 done, avg 0.19s/sample
#     [brain] 8304/19154 done, avg 0.19s/sample
#     [brain] 8352/19154 done, avg 0.19s/sample
#     [brain] 8400/19154 done, avg 0.19s/sample
#     [brain] 8456/19154 done, avg 0.19s/sample
#     [brain] 8504/19154 done, avg 0.19s/sample
#     [brain] 8552/19154 done, avg 0.19s/sample
#     [brain] 8600/19154 done, avg 0.19s/sample
#     [brain] 8656/19154 done, avg 0.19s/sample
#     [brain] 8704/19154 done, avg 0.19s/sample
#     [brain] 8752/19154 done, avg 0.19s/sample
#     [brain] 8800/19154 done, avg 0.19s/sample
#     [brain] 8856/19154 done, avg 0.19s/sample
#     [brain] 8904/19154 done, avg 0.19s/sample
#     [brain] 8952/19154 done, avg 0.18s/sample
#     [brain] 9000/19154 done, avg 0.18s/sample
#     [brain] 9056/19154 done, avg 0.18s/sample
#     [brain] 9104/19154 done, avg 0.19s/sample
#     [brain] 9152/19154 done, avg 0.19s/sample
#     [brain] 9200/19154 done, avg 0.19s/sample
#     [brain] 9256/19154 done, avg 0.18s/sample
#     [brain] 9304/19154 done, avg 0.18s/sample
#     [brain] 9352/19154 done, avg 0.18s/sample
#     [brain] 9400/19154 done, avg 0.18s/sample
#     [brain] 9456/19154 done, avg 0.18s/sample
#     [brain] 9504/19154 done, avg 0.18s/sample
#     [brain] 9552/19154 done, avg 0.18s/sample
#     [brain] 9600/19154 done, avg 0.18s/sample
#     [brain] 9656/19154 done, avg 0.18s/sample
#     [brain] 9704/19154 done, avg 0.18s/sample
#     [brain] 9752/19154 done, avg 0.18s/sample
#     [brain] 9800/19154 done, avg 0.18s/sample
#     [brain] 9856/19154 done, avg 0.18s/sample
#     [brain] 9904/19154 done, avg 0.18s/sample
#     [brain] 9952/19154 done, avg 0.18s/sample
#     [brain] 10000/19154 done, avg 0.18s/sample
#     [brain] 10056/19154 done, avg 0.18s/sample
#     [brain] 10104/19154 done, avg 0.18s/sample
#     [brain] 10152/19154 done, avg 0.18s/sample
#     [brain] 10200/19154 done, avg 0.18s/sample
#     [brain] 10256/19154 done, avg 0.18s/sample
#     [brain] 10304/19154 done, avg 0.18s/sample
#     [brain] 10352/19154 done, avg 0.18s/sample
#     [brain] 10400/19154 done, avg 0.18s/sample
#     [brain] 10456/19154 done, avg 0.18s/sample
#     [brain] 10504/19154 done, avg 0.18s/sample
#     [brain] 10552/19154 done, avg 0.18s/sample
#     [brain] 10600/19154 done, avg 0.18s/sample
#     [brain] 10656/19154 done, avg 0.18s/sample
#     [brain] 10704/19154 done, avg 0.18s/sample
#     [brain] 10752/19154 done, avg 0.18s/sample
#     [brain] 10800/19154 done, avg 0.18s/sample
#     [brain] 10856/19154 done, avg 0.18s/sample
#     [brain] 10904/19154 done, avg 0.18s/sample
#     [brain] 10952/19154 done, avg 0.18s/sample
#     [brain] 11000/19154 done, avg 0.18s/sample
#     [brain] 11056/19154 done, avg 0.18s/sample
#     [brain] 11104/19154 done, avg 0.18s/sample
#     [brain] 11152/19154 done, avg 0.18s/sample
#     [brain] 11200/19154 done, avg 0.18s/sample
#     [brain] 11256/19154 done, avg 0.18s/sample
#     [brain] 11304/19154 done, avg 0.18s/sample
#     [brain] 11352/19154 done, avg 0.18s/sample
#     [brain] 11400/19154 done, avg 0.18s/sample
#     [brain] 11456/19154 done, avg 0.18s/sample
#     [brain] 11504/19154 done, avg 0.18s/sample
#     [brain] 11552/19154 done, avg 0.18s/sample
#     [brain] 11600/19154 done, avg 0.18s/sample
#     [brain] 11656/19154 done, avg 0.18s/sample
#     [brain] 11704/19154 done, avg 0.18s/sample
#     [brain] 11752/19154 done, avg 0.18s/sample
#     [brain] 11800/19154 done, avg 0.18s/sample
#     [brain] 11856/19154 done, avg 0.18s/sample
#     [brain] 11904/19154 done, avg 0.18s/sample
#     [brain] 11952/19154 done, avg 0.18s/sample
#     [brain] 12000/19154 done, avg 0.18s/sample
#     [brain] 12056/19154 done, avg 0.18s/sample
#     [brain] 12104/19154 done, avg 0.18s/sample
#     [brain] 12152/19154 done, avg 0.18s/sample
#     [brain] 12200/19154 done, avg 0.18s/sample
#     [brain] 12256/19154 done, avg 0.18s/sample
#     [brain] 12304/19154 done, avg 0.18s/sample
#     [brain] 12352/19154 done, avg 0.18s/sample
#     [brain] 12400/19154 done, avg 0.18s/sample
#     [brain] 12456/19154 done, avg 0.18s/sample
#     [brain] 12504/19154 done, avg 0.17s/sample
#     [brain] 12552/19154 done, avg 0.17s/sample
#     [brain] 15552/19154 done, avg 0.17s/sample
#     [brain] 15600/19154 done, avg 0.17s/sample
#     [brain] 15656/19154 done, avg 0.17s/sample
#     [brain] 15704/19154 done, avg 0.17s/sample
#     [brain] 15752/19154 done, avg 0.17s/sample
#     [brain] 15800/19154 done, avg 0.17s/sample
#     [brain] 15856/19154 done, avg 0.17s/sample
#     [brain] 15904/19154 done, avg 0.17s/sample
#     [brain] 15952/19154 done, avg 0.17s/sample
#     [brain] 16000/19154 done, avg 0.17s/sample
#     [brain] 16056/19154 done, avg 0.17s/sample
#     [brain] 16104/19154 done, avg 0.17s/sample
#     [brain] 16152/19154 done, avg 0.17s/sample
#     [brain] 16200/19154 done, avg 0.17s/sample
#     [brain] 16256/19154 done, avg 0.17s/sample
#     [brain] 16304/19154 done, avg 0.17s/sample
#     [brain] 16352/19154 done, avg 0.17s/sample
#     [brain] 16400/19154 done, avg 0.17s/sample
#     [brain] 16456/19154 done, avg 0.17s/sample
#     [brain] 16504/19154 done, avg 0.17s/sample
#     [brain] 16552/19154 done, avg 0.17s/sample
#     [brain] 16600/19154 done, avg 0.17s/sample
#     [brain] 16656/19154 done, avg 0.17s/sample
#     [brain] 16704/19154 done, avg 0.16s/sample
#     [brain] 16752/19154 done, avg 0.16s/sample
#     [brain] 16800/19154 done, avg 0.16s/sample
#     [brain] 16856/19154 done, avg 0.16s/sample
#     [brain] 16904/19154 done, avg 0.16s/sample
#     [brain] 16952/19154 done, avg 0.16s/sample
#     [brain] 17000/19154 done, avg 0.16s/sample
#     [brain] 17056/19154 done, avg 0.16s/sample
#     [brain] 17104/19154 done, avg 0.16s/sample
#     [brain] 17152/19154 done, avg 0.16s/sample
#     [brain] 17200/19154 done, avg 0.16s/sample
#     [brain] 17256/19154 done, avg 0.16s/sample
#     [brain] 17304/19154 done, avg 0.16s/sample
#     [brain] 17352/19154 done, avg 0.16s/sample
#     [brain] 17400/19154 done, avg 0.16s/sample
#     [brain] 17456/19154 done, avg 0.16s/sample
#     [brain] 17504/19154 done, avg 0.16s/sample
#     [brain] 17552/19154 done, avg 0.16s/sample
#     [brain] 17600/19154 done, avg 0.16s/sample
#     [brain] 17656/19154 done, avg 0.16s/sample
#     [brain] 17704/19154 done, avg 0.16s/sample
#     [brain] 17752/19154 done, avg 0.16s/sample
#     [brain] 17800/19154 done, avg 0.16s/sample
#     [brain] 17856/19154 done, avg 0.16s/sample
#     [brain] 17904/19154 done, avg 0.16s/sample
#     [brain] 17952/19154 done, avg 0.16s/sample
#     [brain] 18000/19154 done, avg 0.16s/sample
#     [brain] 18056/19154 done, avg 0.16s/sample
#     [brain] 18104/19154 done, avg 0.16s/sample
#     [brain] 18152/19154 done, avg 0.16s/sample
#     [brain] 18200/19154 done, avg 0.16s/sample
#     [brain] 18256/19154 done, avg 0.16s/sample
#     [brain] 18304/19154 done, avg 0.16s/sample
#     [brain] 18352/19154 done, avg 0.16s/sample
#     [brain] 18400/19154 done, avg 0.16s/sample
#     [brain] 18456/19154 done, avg 0.16s/sample
#     [brain] 18504/19154 done, avg 0.16s/sample
#     [brain] 18552/19154 done, avg 0.16s/sample
#     [brain] 18600/19154 done, avg 0.16s/sample
#     [brain] 18656/19154 done, avg 0.16s/sample
#     [brain] 18704/19154 done, avg 0.16s/sample
#     [brain] 18752/19154 done, avg 0.16s/sample
#     [brain] 18800/19154 done, avg 0.16s/sample
#     [brain] 18856/19154 done, avg 0.16s/sample
#     [brain] 18904/19154 done, avg 0.16s/sample
#     [brain] 18952/19154 done, avg 0.16s/sample
#     [brain] 19000/19154 done, avg 0.16s/sample
#     [brain] 19056/19154 done, avg 0.16s/sample
#     [brain] 19104/19154 done, avg 0.16s/sample
#     [brain] 19152/19154 done, avg 0.16s/sample
#     [brain] 19154/19154 done, avg 0.16s/sample
#   -> [BRAIN] Done. Running total time: 4317.68s
# [BONE] Processing 25169/25169 samples (batch_size=8, use_true_label=True)...
#     [bone] 56/25169 done, avg 0.16s/sample
#     [bone] 104/25169 done, avg 0.16s/sample
#     [bone] 152/25169 done, avg 0.16s/sample
#     [bone] 200/25169 done, avg 0.16s/sample
#     [bone] 256/25169 done, avg 0.16s/sample
#     [bone] 304/25169 done, avg 0.16s/sample
#     [bone] 352/25169 done, avg 0.16s/sample
#     [bone] 400/25169 done, avg 0.16s/sample
#     [bone] 456/25169 done, avg 0.16s/sample
#     [bone] 504/25169 done, avg 0.16s/sample
#     [bone] 552/25169 done, avg 0.16s/sample
#     [bone] 600/25169 done, avg 0.16s/sample
#     [bone] 656/25169 done, avg 0.16s/sample
#     [bone] 704/25169 done, avg 0.16s/sample
#     [bone] 752/25169 done, avg 0.16s/sample
#     [bone] 800/25169 done, avg 0.16s/sample
#     [bone] 856/25169 done, avg 0.16s/sample
#     [bone] 904/25169 done, avg 0.16s/sample
#     [bone] 952/25169 done, avg 0.16s/sample
#     [bone] 1000/25169 done, avg 0.16s/sample
#     [bone] 1056/25169 done, avg 0.16s/sample
#     [bone] 1104/25169 done, avg 0.16s/sample
#     [bone] 1152/25169 done, avg 0.16s/sample
#     [bone] 1200/25169 done, avg 0.16s/sample
#     [bone] 1256/25169 done, avg 0.16s/sample
#     [bone] 1304/25169 done, avg 0.16s/sample
#     [bone] 1352/25169 done, avg 0.16s/sample
#     [bone] 1400/25169 done, avg 0.16s/sample
#     [bone] 1456/25169 done, avg 0.16s/sample
#     [bone] 1504/25169 done, avg 0.16s/sample
#     [bone] 1552/25169 done, avg 0.16s/sample
#     [bone] 1600/25169 done, avg 0.16s/sample
#     [bone] 1656/25169 done, avg 0.16s/sample
#     [bone] 1704/25169 done, avg 0.16s/sample
#     [bone] 1752/25169 done, avg 0.16s/sample
#     [bone] 1800/25169 done, avg 0.16s/sample
#     [bone] 1856/25169 done, avg 0.16s/sample
#     [bone] 1904/25169 done, avg 0.16s/sample
#     [bone] 1952/25169 done, avg 0.16s/sample
#     [bone] 2000/25169 done, avg 0.16s/sample
#     [bone] 2056/25169 done, avg 0.16s/sample
#     [bone] 2104/25169 done, avg 0.16s/sample
#     [bone] 2152/25169 done, avg 0.16s/sample
#     [bone] 2200/25169 done, avg 0.16s/sample
#     [bone] 2256/25169 done, avg 0.16s/sample
#     [bone] 2304/25169 done, avg 0.16s/sample
#     [bone] 2352/25169 done, avg 0.16s/sample
#     [bone] 2400/25169 done, avg 0.16s/sample
#     [bone] 2456/25169 done, avg 0.16s/sample
#     [bone] 2504/25169 done, avg 0.16s/sample
#     [bone] 2552/25169 done, avg 0.16s/sample
#     [bone] 2600/25169 done, avg 0.16s/sample
#     [bone] 2656/25169 done, avg 0.16s/sample
#     [bone] 2704/25169 done, avg 0.16s/sample
#     [bone] 2752/25169 done, avg 0.16s/sample
#     [bone] 2800/25169 done, avg 0.16s/sample
#     [bone] 2856/25169 done, avg 0.16s/sample
#     [bone] 2904/25169 done, avg 0.16s/sample
#     [bone] 2952/25169 done, avg 0.16s/sample
#     [bone] 3000/25169 done, avg 0.16s/sample
#     [bone] 3056/25169 done, avg 0.16s/sample
#     [bone] 3104/25169 done, avg 0.16s/sample
#     [bone] 3152/25169 done, avg 0.16s/sample
#     [bone] 3200/25169 done, avg 0.16s/sample
#     [bone] 3256/25169 done, avg 0.16s/sample
#     [bone] 3304/25169 done, avg 0.16s/sample
#     [bone] 3352/25169 done, avg 0.16s/sample
#     [bone] 3400/25169 done, avg 0.16s/sample
#     [bone] 3456/25169 done, avg 0.16s/sample
#     [bone] 3504/25169 done, avg 0.16s/sample
#     [bone] 3552/25169 done, avg 0.16s/sample
#     [bone] 3600/25169 done, avg 0.16s/sample
#     [bone] 3656/25169 done, avg 0.16s/sample
#     [bone] 3704/25169 done, avg 0.16s/sample
#     [bone] 3752/25169 done, avg 0.16s/sample
#     [bone] 3800/25169 done, avg 0.16s/sample
#     [bone] 3856/25169 done, avg 0.16s/sample
#     [bone] 3904/25169 done, avg 0.16s/sample
#     [bone] 3952/25169 done, avg 0.16s/sample
#     [bone] 4000/25169 done, avg 0.16s/sample
#     [bone] 4056/25169 done, avg 0.16s/sample
#     [bone] 4104/25169 done, avg 0.16s/sample
#     [bone] 4152/25169 done, avg 0.16s/sample
#     [bone] 4200/25169 done, avg 0.16s/sample
#     [bone] 4256/25169 done, avg 0.16s/sample
#     [bone] 4304/25169 done, avg 0.16s/sample
#     [bone] 4352/25169 done, avg 0.16s/sample
#     [bone] 4400/25169 done, avg 0.16s/sample
#     [bone] 4456/25169 done, avg 0.16s/sample
#     [bone] 4504/25169 done, avg 0.16s/sample
#     [bone] 4552/25169 done, avg 0.16s/sample
#     [bone] 4600/25169 done, avg 0.16s/sample
#     [bone] 4656/25169 done, avg 0.16s/sample
#     [bone] 4704/25169 done, avg 0.16s/sample
#     [bone] 4752/25169 done, avg 0.16s/sample
#     [bone] 4800/25169 done, avg 0.16s/sample
#     [bone] 4856/25169 done, avg 0.16s/sample
#     [bone] 4904/25169 done, avg 0.16s/sample
#     [bone] 4952/25169 done, avg 0.16s/sample
#     [bone] 5000/25169 done, avg 0.16s/sample
#     [bone] 5056/25169 done, avg 0.16s/sample
#     [bone] 5104/25169 done, avg 0.16s/sample
#     [bone] 5152/25169 done, avg 0.16s/sample
#     [bone] 5200/25169 done, avg 0.16s/sample
#     [bone] 5256/25169 done, avg 0.16s/sample
#     [bone] 5304/25169 done, avg 0.16s/sample
#     [bone] 5352/25169 done, avg 0.16s/sample
#     [bone] 5400/25169 done, avg 0.16s/sample
#     [bone] 5456/25169 done, avg 0.16s/sample
#     [bone] 5504/25169 done, avg 0.16s/sample
#     [bone] 5552/25169 done, avg 0.16s/sample
#     [bone] 5600/25169 done, avg 0.16s/sample
#     [bone] 5656/25169 done, avg 0.16s/sample
#     [bone] 5704/25169 done, avg 0.16s/sample
#     [bone] 5752/25169 done, avg 0.16s/sample
#     [bone] 5800/25169 done, avg 0.16s/sample
#     [bone] 5856/25169 done, avg 0.16s/sample
#     [bone] 5904/25169 done, avg 0.16s/sample
#     [bone] 5952/25169 done, avg 0.16s/sample
#     [bone] 6000/25169 done, avg 0.16s/sample
#     [bone] 6056/25169 done, avg 0.16s/sample
#     [bone] 6104/25169 done, avg 0.16s/sample
#     [bone] 6152/25169 done, avg 0.16s/sample
#     [bone] 6200/25169 done, avg 0.15s/sample
#     [bone] 6256/25169 done, avg 0.15s/sample
#     [bone] 6304/25169 done, avg 0.15s/sample
#     [bone] 6352/25169 done, avg 0.15s/sample
#     [bone] 6400/25169 done, avg 0.15s/sample
#     [bone] 6456/25169 done, avg 0.15s/sample
#     [bone] 6504/25169 done, avg 0.15s/sample
#     [bone] 6552/25169 done, avg 0.15s/sample
#     [bone] 6600/25169 done, avg 0.15s/sample
#     [bone] 6656/25169 done, avg 0.15s/sample
#     [bone] 6704/25169 done, avg 0.15s/sample
#     [bone] 6752/25169 done, avg 0.15s/sample
#     [bone] 6800/25169 done, avg 0.15s/sample
#     [bone] 6856/25169 done, avg 0.15s/sample
#     [bone] 6904/25169 done, avg 0.15s/sample
#     [bone] 6952/25169 done, avg 0.15s/sample
#     [bone] 7000/25169 done, avg 0.15s/sample
#     [bone] 7056/25169 done, avg 0.15s/sample
#     [bone] 7104/25169 done, avg 0.15s/sample
#     [bone] 7152/25169 done, avg 0.15s/sample
#     [bone] 7200/25169 done, avg 0.15s/sample
#     [bone] 7256/25169 done, avg 0.15s/sample
#     [bone] 7304/25169 done, avg 0.15s/sample
#     [bone] 7352/25169 done, avg 0.15s/sample
#     [bone] 7400/25169 done, avg 0.15s/sample
#     [bone] 7456/25169 done, avg 0.15s/sample
#     [bone] 7504/25169 done, avg 0.15s/sample
#     [bone] 7552/25169 done, avg 0.15s/sample
#     [bone] 7600/25169 done, avg 0.15s/sample
#     [bone] 7656/25169 done, avg 0.15s/sample
#     [bone] 7704/25169 done, avg 0.15s/sample
#     [bone] 7752/25169 done, avg 0.15s/sample
#     [bone] 7800/25169 done, avg 0.15s/sample
#     [bone] 7856/25169 done, avg 0.15s/sample
#     [bone] 7904/25169 done, avg 0.15s/sample
#     [bone] 7952/25169 done, avg 0.15s/sample
#     [bone] 8000/25169 done, avg 0.15s/sample
#     [bone] 8056/25169 done, avg 0.15s/sample
#     [bone] 8104/25169 done, avg 0.15s/sample
#     [bone] 8152/25169 done, avg 0.15s/sample
#     [bone] 8200/25169 done, avg 0.15s/sample
#     [bone] 8256/25169 done, avg 0.15s/sample
#     [bone] 8304/25169 done, avg 0.15s/sample
#     [bone] 8352/25169 done, avg 0.15s/sample
#     [bone] 8400/25169 done, avg 0.15s/sample
#     [bone] 8456/25169 done, avg 0.15s/sample
#     [bone] 8504/25169 done, avg 0.15s/sample
#     [bone] 8552/25169 done, avg 0.15s/sample
#     [bone] 8600/25169 done, avg 0.15s/sample
#     [bone] 8656/25169 done, avg 0.15s/sample
#     [bone] 8704/25169 done, avg 0.15s/sample
#     [bone] 8752/25169 done, avg 0.15s/sample
#     [bone] 8800/25169 done, avg 0.15s/sample
#     [bone] 8856/25169 done, avg 0.15s/sample
#     [bone] 8904/25169 done, avg 0.15s/sample
#     [bone] 8952/25169 done, avg 0.15s/sample
#     [bone] 9000/25169 done, avg 0.15s/sample
#     [bone] 9056/25169 done, avg 0.15s/sample
#     [bone] 9104/25169 done, avg 0.15s/sample
#     [bone] 9152/25169 done, avg 0.15s/sample
#     [bone] 9200/25169 done, avg 0.15s/sample
#     [bone] 9256/25169 done, avg 0.15s/sample
#     [bone] 9304/25169 done, avg 0.15s/sample
#     [bone] 9352/25169 done, avg 0.15s/sample
#     [bone] 9400/25169 done, avg 0.15s/sample
#     [bone] 9456/25169 done, avg 0.15s/sample
#     [bone] 9504/25169 done, avg 0.15s/sample
#     [bone] 9552/25169 done, avg 0.15s/sample
#     [bone] 9600/25169 done, avg 0.15s/sample
#     [bone] 9656/25169 done, avg 0.15s/sample
#     [bone] 9704/25169 done, avg 0.15s/sample
#     [bone] 9752/25169 done, avg 0.15s/sample
#     [bone] 9800/25169 done, avg 0.15s/sample
#     [bone] 9856/25169 done, avg 0.15s/sample
#     [bone] 9904/25169 done, avg 0.15s/sample
#     [bone] 9952/25169 done, avg 0.15s/sample
#     [bone] 10000/25169 done, avg 0.15s/sample
#     [bone] 10056/25169 done, avg 0.15s/sample
#     [bone] 10104/25169 done, avg 0.15s/sample
#     [bone] 10152/25169 done, avg 0.15s/sample
#     [bone] 10200/25169 done, avg 0.15s/sample
#     [bone] 10256/25169 done, avg 0.15s/sample
#     [bone] 10304/25169 done, avg 0.15s/sample
#     [bone] 10352/25169 done, avg 0.15s/sample
#     [bone] 10400/25169 done, avg 0.15s/sample
#     [bone] 10456/25169 done, avg 0.15s/sample
#     [bone] 10504/25169 done, avg 0.15s/sample
#     [bone] 10552/25169 done, avg 0.15s/sample
#     [bone] 10600/25169 done, avg 0.15s/sample
#     [bone] 10656/25169 done, avg 0.15s/sample
#     [bone] 10704/25169 done, avg 0.15s/sample
#     [bone] 10752/25169 done, avg 0.15s/sample
#     [bone] 10800/25169 done, avg 0.15s/sample
#     [bone] 10856/25169 done, avg 0.15s/sample
#     [bone] 10904/25169 done, avg 0.15s/sample
#     [bone] 10952/25169 done, avg 0.15s/sample
#     [bone] 11000/25169 done, avg 0.15s/sample
#     [bone] 11056/25169 done, avg 0.15s/sample
#     [bone] 11104/25169 done, avg 0.15s/sample
#     [bone] 11152/25169 done, avg 0.15s/sample
#     [bone] 11200/25169 done, avg 0.15s/sample
#     [bone] 11256/25169 done, avg 0.15s/sample
#     [bone] 11304/25169 done, avg 0.15s/sample
#     [bone] 11352/25169 done, avg 0.15s/sample
#     [bone] 11400/25169 done, avg 0.15s/sample
#     [bone] 11456/25169 done, avg 0.15s/sample
#     [bone] 11504/25169 done, avg 0.15s/sample
#     [bone] 11552/25169 done, avg 0.15s/sample
#     [bone] 11600/25169 done, avg 0.15s/sample
#     [bone] 11656/25169 done, avg 0.15s/sample
#     [bone] 11704/25169 done, avg 0.15s/sample
#     [bone] 11752/25169 done, avg 0.15s/sample
#     [bone] 11800/25169 done, avg 0.15s/sample
#     [bone] 11856/25169 done, avg 0.15s/sample
#     [bone] 11904/25169 done, avg 0.15s/sample
#     [bone] 11952/25169 done, avg 0.15s/sample
#     [bone] 12000/25169 done, avg 0.15s/sample
#     [bone] 12056/25169 done, avg 0.15s/sample
#     [bone] 12104/25169 done, avg 0.15s/sample
#     [bone] 12152/25169 done, avg 0.15s/sample
#     [bone] 12200/25169 done, avg 0.15s/sample
#     [bone] 12256/25169 done, avg 0.15s/sample
#     [bone] 12304/25169 done, avg 0.15s/sample
#     [bone] 12352/25169 done, avg 0.15s/sample
#     [bone] 12400/25169 done, avg 0.15s/sample
#     [bone] 12456/25169 done, avg 0.15s/sample
#     [bone] 12504/25169 done, avg 0.15s/sample
#     [bone] 12552/25169 done, avg 0.15s/sample
#     [bone] 12600/25169 done, avg 0.15s/sample
#     [bone] 12656/25169 done, avg 0.15s/sample
#     [bone] 12704/25169 done, avg 0.15s/sample
#     [bone] 12752/25169 done, avg 0.15s/sample
#     [bone] 12800/25169 done, avg 0.15s/sample
#     [bone] 12856/25169 done, avg 0.15s/sample
#     [bone] 12904/25169 done, avg 0.15s/sample
#     [bone] 12952/25169 done, avg 0.15s/sample
#     [bone] 13000/25169 done, avg 0.15s/sample
#     [bone] 13056/25169 done, avg 0.15s/sample
#     [bone] 13104/25169 done, avg 0.15s/sample
#     [bone] 13152/25169 done, avg 0.15s/sample
#     [bone] 13200/25169 done, avg 0.15s/sample
#     [bone] 13256/25169 done, avg 0.15s/sample
#     [bone] 13304/25169 done, avg 0.15s/sample
#     [bone] 13352/25169 done, avg 0.15s/sample
#     [bone] 13400/25169 done, avg 0.15s/sample
#     [bone] 13456/25169 done, avg 0.15s/sample
#     [bone] 13504/25169 done, avg 0.15s/sample
#     [bone] 13552/25169 done, avg 0.15s/sample
#     [bone] 13600/25169 done, avg 0.15s/sample
#     [bone] 13656/25169 done, avg 0.15s/sample
#     [bone] 13704/25169 done, avg 0.15s/sample
#     [bone] 13752/25169 done, avg 0.15s/sample
#     [bone] 13800/25169 done, avg 0.15s/sample
#     [bone] 13856/25169 done, avg 0.15s/sample
#     [bone] 13904/25169 done, avg 0.15s/sample
#     [bone] 13952/25169 done, avg 0.15s/sample
#     [bone] 14000/25169 done, avg 0.15s/sample
#     [bone] 14056/25169 done, avg 0.15s/sample
#     [bone] 14104/25169 done, avg 0.15s/sample
#     [bone] 14152/25169 done, avg 0.15s/sample
#     [bone] 14200/25169 done, avg 0.15s/sample
#     [bone] 14256/25169 done, avg 0.15s/sample
#     [bone] 14304/25169 done, avg 0.15s/sample
#     [bone] 14352/25169 done, avg 0.15s/sample
#     [bone] 14400/25169 done, avg 0.15s/sample
#     [bone] 14456/25169 done, avg 0.15s/sample
#     [bone] 14504/25169 done, avg 0.15s/sample
#     [bone] 14552/25169 done, avg 0.15s/sample
#     [bone] 14600/25169 done, avg 0.15s/sample
#     [bone] 14656/25169 done, avg 0.15s/sample
#     [bone] 14704/25169 done, avg 0.15s/sample
#     [bone] 14752/25169 done, avg 0.15s/sample
#     [bone] 14800/25169 done, avg 0.15s/sample
#     [bone] 14856/25169 done, avg 0.15s/sample
#     [bone] 14904/25169 done, avg 0.15s/sample
#     [bone] 14952/25169 done, avg 0.15s/sample
#     [bone] 15000/25169 done, avg 0.15s/sample
#     [bone] 15056/25169 done, avg 0.15s/sample
#     [bone] 15104/25169 done, avg 0.15s/sample
#     [bone] 15152/25169 done, avg 0.15s/sample
#     [bone] 15200/25169 done, avg 0.15s/sample
#     [bone] 15256/25169 done, avg 0.15s/sample
#     [bone] 15304/25169 done, avg 0.15s/sample
#     [bone] 15352/25169 done, avg 0.15s/sample
#     [bone] 15400/25169 done, avg 0.15s/sample
#     [bone] 15456/25169 done, avg 0.15s/sample
#     [bone] 15504/25169 done, avg 0.15s/sample
#     [bone] 15552/25169 done, avg 0.15s/sample
#     [bone] 15600/25169 done, avg 0.15s/sample
#     [bone] 15656/25169 done, avg 0.15s/sample
#     [bone] 15704/25169 done, avg 0.15s/sample
#     [bone] 15752/25169 done, avg 0.15s/sample
#     [bone] 15800/25169 done, avg 0.15s/sample
#     [bone] 15856/25169 done, avg 0.15s/sample
#     [bone] 15904/25169 done, avg 0.14s/sample
#     [bone] 15952/25169 done, avg 0.14s/sample
#     [bone] 16000/25169 done, avg 0.14s/sample
#     [bone] 16056/25169 done, avg 0.14s/sample
#     [bone] 16104/25169 done, avg 0.14s/sample
#     [bone] 16152/25169 done, avg 0.14s/sample
#     [bone] 16200/25169 done, avg 0.14s/sample
#     [bone] 16256/25169 done, avg 0.14s/sample
#     [bone] 16304/25169 done, avg 0.14s/sample
#     [bone] 16352/25169 done, avg 0.14s/sample
#     [bone] 16400/25169 done, avg 0.14s/sample
#     [bone] 16456/25169 done, avg 0.14s/sample
#     [bone] 16504/25169 done, avg 0.14s/sample
#     [bone] 16552/25169 done, avg 0.14s/sample
#     [bone] 16600/25169 done, avg 0.14s/sample
#     [bone] 16656/25169 done, avg 0.14s/sample
#     [bone] 16704/25169 done, avg 0.14s/sample
#     [bone] 16752/25169 done, avg 0.14s/sample
#     [bone] 16800/25169 done, avg 0.14s/sample
#     [bone] 16856/25169 done, avg 0.14s/sample
#     [bone] 16904/25169 done, avg 0.14s/sample
#     [bone] 16952/25169 done, avg 0.14s/sample
#     [bone] 17000/25169 done, avg 0.14s/sample
#     [bone] 17056/25169 done, avg 0.14s/sample
#     [bone] 17104/25169 done, avg 0.14s/sample
#     [bone] 17152/25169 done, avg 0.14s/sample
#     [bone] 17200/25169 done, avg 0.14s/sample
#     [bone] 17256/25169 done, avg 0.14s/sample
#     [bone] 17304/25169 done, avg 0.14s/sample
#     [bone] 17352/25169 done, avg 0.14s/sample
#     [bone] 17400/25169 done, avg 0.14s/sample
#     [bone] 17456/25169 done, avg 0.14s/sample
#     [bone] 17504/25169 done, avg 0.14s/sample
#     [bone] 17552/25169 done, avg 0.14s/sample
#     [bone] 17600/25169 done, avg 0.14s/sample
#     [bone] 17656/25169 done, avg 0.14s/sample
#     [bone] 17704/25169 done, avg 0.14s/sample
#     [bone] 17752/25169 done, avg 0.14s/sample
#     [bone] 17800/25169 done, avg 0.14s/sample
#     [bone] 17856/25169 done, avg 0.14s/sample
#     [bone] 17904/25169 done, avg 0.14s/sample
#     [bone] 17952/25169 done, avg 0.14s/sample
#     [bone] 18000/25169 done, avg 0.14s/sample
#     [bone] 18056/25169 done, avg 0.14s/sample
#     [bone] 18104/25169 done, avg 0.14s/sample
#     [bone] 18152/25169 done, avg 0.14s/sample
#     [bone] 18200/25169 done, avg 0.14s/sample
#     [bone] 18256/25169 done, avg 0.14s/sample
#     [bone] 18304/25169 done, avg 0.14s/sample
#     [bone] 18352/25169 done, avg 0.14s/sample
#     [bone] 18400/25169 done, avg 0.14s/sample
#     [bone] 18456/25169 done, avg 0.14s/sample
#     [bone] 18504/25169 done, avg 0.14s/sample
#     [bone] 18552/25169 done, avg 0.14s/sample
#     [bone] 18600/25169 done, avg 0.14s/sample
#     [bone] 18656/25169 done, avg 0.14s/sample
#     [bone] 18704/25169 done, avg 0.14s/sample
#     [bone] 18752/25169 done, avg 0.14s/sample
#     [bone] 18800/25169 done, avg 0.14s/sample
#     [bone] 18856/25169 done, avg 0.14s/sample
#     [bone] 18904/25169 done, avg 0.14s/sample
#     [bone] 18952/25169 done, avg 0.14s/sample
#     [bone] 19000/25169 done, avg 0.14s/sample
#     [bone] 19056/25169 done, avg 0.14s/sample
#     [bone] 19104/25169 done, avg 0.14s/sample
#     [bone] 19152/25169 done, avg 0.14s/sample
#     [bone] 19200/25169 done, avg 0.14s/sample
#     [bone] 19256/25169 done, avg 0.14s/sample
#     [bone] 19304/25169 done, avg 0.14s/sample
#     [bone] 19352/25169 done, avg 0.14s/sample
#     [bone] 19400/25169 done, avg 0.14s/sample
#     [bone] 19456/25169 done, avg 0.14s/sample
#     [bone] 19504/25169 done, avg 0.14s/sample
#     [bone] 19552/25169 done, avg 0.14s/sample
#     [bone] 19600/25169 done, avg 0.14s/sample
#     [bone] 19656/25169 done, avg 0.14s/sample
#     [bone] 19704/25169 done, avg 0.14s/sample
#     [bone] 19752/25169 done, avg 0.14s/sample
#     [bone] 19800/25169 done, avg 0.14s/sample
#     [bone] 19856/25169 done, avg 0.14s/sample
#     [bone] 19904/25169 done, avg 0.14s/sample
#     [bone] 19952/25169 done, avg 0.14s/sample
#     [bone] 20000/25169 done, avg 0.14s/sample
#     [bone] 20056/25169 done, avg 0.14s/sample
#     [bone] 20104/25169 done, avg 0.14s/sample
#     [bone] 20152/25169 done, avg 0.14s/sample
#     [bone] 20200/25169 done, avg 0.14s/sample
#     [bone] 20256/25169 done, avg 0.14s/sample
#     [bone] 20304/25169 done, avg 0.14s/sample
#     [bone] 20352/25169 done, avg 0.14s/sample
#     [bone] 20400/25169 done, avg 0.14s/sample
#     [bone] 20456/25169 done, avg 0.14s/sample
#     [bone] 20504/25169 done, avg 0.14s/sample
#     [bone] 20552/25169 done, avg 0.14s/sample
#     [bone] 20600/25169 done, avg 0.14s/sample
#     [bone] 20656/25169 done, avg 0.14s/sample
#     [bone] 20704/25169 done, avg 0.14s/sample
#     [bone] 20752/25169 done, avg 0.14s/sample
#     [bone] 20800/25169 done, avg 0.14s/sample
#     [bone] 20856/25169 done, avg 0.14s/sample
#     [bone] 20904/25169 done, avg 0.14s/sample
#     [bone] 20952/25169 done, avg 0.14s/sample
#     [bone] 21000/25169 done, avg 0.14s/sample
#     [bone] 21056/25169 done, avg 0.14s/sample
#     [bone] 21104/25169 done, avg 0.14s/sample
#     [bone] 21152/25169 done, avg 0.14s/sample
#     [bone] 21200/25169 done, avg 0.14s/sample
#     [bone] 21256/25169 done, avg 0.14s/sample
#     [bone] 21304/25169 done, avg 0.14s/sample
#     [bone] 21352/25169 done, avg 0.14s/sample
#     [bone] 21400/25169 done, avg 0.14s/sample
#     [bone] 21456/25169 done, avg 0.14s/sample
#     [bone] 21504/25169 done, avg 0.14s/sample
#     [bone] 21552/25169 done, avg 0.14s/sample
#     [bone] 21600/25169 done, avg 0.14s/sample
#     [bone] 21656/25169 done, avg 0.14s/sample
#     [bone] 21704/25169 done, avg 0.14s/sample
#     [bone] 21752/25169 done, avg 0.14s/sample
#     [bone] 21800/25169 done, avg 0.14s/sample
#     [bone] 21856/25169 done, avg 0.14s/sample
#     [bone] 21904/25169 done, avg 0.14s/sample
#     [bone] 21952/25169 done, avg 0.14s/sample
#     [bone] 22000/25169 done, avg 0.14s/sample
#     [bone] 22056/25169 done, avg 0.14s/sample
#     [bone] 22104/25169 done, avg 0.14s/sample
#     [bone] 22152/25169 done, avg 0.14s/sample
#     [bone] 22200/25169 done, avg 0.14s/sample
#     [bone] 22256/25169 done, avg 0.14s/sample
#     [bone] 22304/25169 done, avg 0.14s/sample
#     [bone] 22352/25169 done, avg 0.14s/sample
#     [bone] 22400/25169 done, avg 0.14s/sample
#     [bone] 22456/25169 done, avg 0.14s/sample
#     [bone] 22504/25169 done, avg 0.14s/sample
#     [bone] 22552/25169 done, avg 0.14s/sample
#     [bone] 22600/25169 done, avg 0.14s/sample
#     [bone] 22656/25169 done, avg 0.14s/sample
#     [bone] 22704/25169 done, avg 0.14s/sample
#     [bone] 22752/25169 done, avg 0.14s/sample
#     [bone] 22800/25169 done, avg 0.14s/sample
#     [bone] 22856/25169 done, avg 0.14s/sample
#     [bone] 22904/25169 done, avg 0.14s/sample
#     [bone] 22952/25169 done, avg 0.14s/sample
#     [bone] 23000/25169 done, avg 0.14s/sample
#     [bone] 23056/25169 done, avg 0.14s/sample
#     [bone] 23104/25169 done, avg 0.14s/sample
#     [bone] 23152/25169 done, avg 0.14s/sample
#     [bone] 23200/25169 done, avg 0.14s/sample
#     [bone] 23256/25169 done, avg 0.14s/sample
#     [bone] 23304/25169 done, avg 0.14s/sample
#     [bone] 23352/25169 done, avg 0.14s/sample
#     [bone] 23400/25169 done, avg 0.14s/sample
#     [bone] 23456/25169 done, avg 0.14s/sample
#     [bone] 23504/25169 done, avg 0.14s/sample
#     [bone] 23552/25169 done, avg 0.14s/sample
#     [bone] 23600/25169 done, avg 0.14s/sample
#     [bone] 23656/25169 done, avg 0.14s/sample
#     [bone] 23704/25169 done, avg 0.14s/sample
#     [bone] 23752/25169 done, avg 0.14s/sample
#     [bone] 23800/25169 done, avg 0.14s/sample
#     [bone] 23856/25169 done, avg 0.14s/sample
#     [bone] 23904/25169 done, avg 0.14s/sample
#     [bone] 23952/25169 done, avg 0.14s/sample
#     [bone] 24000/25169 done, avg 0.14s/sample
#     [bone] 24056/25169 done, avg 0.14s/sample
#     [bone] 24104/25169 done, avg 0.14s/sample
#     [bone] 24152/25169 done, avg 0.14s/sample
# ...
#     [liver] 552/3859 done, avg 0.14s/sample
#     [liver] 600/3859 done, avg 0.14s/sample
#     [liver] 656/3859 done, avg 0.14s/sample
#     [liver] 704/3859 done, avg 0.14s/sample
#     [liver] 752/3859 done, avg 0.14s/sample
#     [liver] 800/3859 done, avg 0.14s/sample
#     [liver] 856/3859 done, avg 0.14s/sample
#     [liver] 904/3859 done, avg 0.14s/sample
#     [liver] 952/3859 done, avg 0.14s/sample
#     [liver] 1000/3859 done, avg 0.14s/sample
#     [liver] 1056/3859 done, avg 0.14s/sample
#     [liver] 1104/3859 done, avg 0.14s/sample
#     [liver] 1152/3859 done, avg 0.14s/sample
#     [liver] 1200/3859 done, avg 0.14s/sample
#     [liver] 1256/3859 done, avg 0.14s/sample
#     [liver] 1304/3859 done, avg 0.14s/sample
#     [liver] 1352/3859 done, avg 0.14s/sample
#     [liver] 1400/3859 done, avg 0.14s/sample
#     [liver] 1456/3859 done, avg 0.14s/sample
#     [liver] 1504/3859 done, avg 0.14s/sample
#     [liver] 1552/3859 done, avg 0.14s/sample
#     [liver] 1600/3859 done, avg 0.14s/sample
#     [liver] 1656/3859 done, avg 0.14s/sample
#     [liver] 1704/3859 done, avg 0.14s/sample
#     [liver] 1752/3859 done, avg 0.14s/sample
#     [liver] 1800/3859 done, avg 0.14s/sample
#     [liver] 1856/3859 done, avg 0.14s/sample
#     [liver] 1904/3859 done, avg 0.14s/sample
#     [liver] 1952/3859 done, avg 0.14s/sample
#     [liver] 2000/3859 done, avg 0.14s/sample
#     [liver] 2056/3859 done, avg 0.14s/sample
#     [liver] 2104/3859 done, avg 0.14s/sample
#     [liver] 2152/3859 done, avg 0.14s/sample
#     [liver] 2200/3859 done, avg 0.14s/sample
#     [liver] 2256/3859 done, avg 0.14s/sample
#     [liver] 2304/3859 done, avg 0.14s/sample
#     [liver] 2352/3859 done, avg 0.14s/sample
#     [liver] 2400/3859 done, avg 0.14s/sample
#     [liver] 2456/3859 done, avg 0.14s/sample
#     [liver] 2504/3859 done, avg 0.14s/sample
#     [liver] 2552/3859 done, avg 0.14s/sample
#     [liver] 2600/3859 done, avg 0.14s/sample
#     [liver] 2656/3859 done, avg 0.14s/sample
#     [liver] 2704/3859 done, avg 0.14s/sample
#     [liver] 2752/3859 done, avg 0.14s/sample
#     [liver] 2800/3859 done, avg 0.14s/sample
#     [liver] 2856/3859 done, avg 0.14s/sample
#     [liver] 2904/3859 done, avg 0.14s/sample
#     [liver] 2952/3859 done, avg 0.14s/sample
#     [liver] 3000/3859 done, avg 0.14s/sample
#     [liver] 3056/3859 done, avg 0.14s/sample
#     [liver] 3104/3859 done, avg 0.14s/sample
#     [liver] 3152/3859 done, avg 0.14s/sample
#     [liver] 3200/3859 done, avg 0.14s/sample
#     [liver] 3256/3859 done, avg 0.14s/sample
#     [liver] 3304/3859 done, avg 0.14s/sample
#     [liver] 3352/3859 done, avg 0.14s/sample
#     [liver] 3400/3859 done, avg 0.14s/sample
#     [liver] 3456/3859 done, avg 0.14s/sample
#     [liver] 3504/3859 done, avg 0.14s/sample
#     [liver] 3552/3859 done, avg 0.14s/sample
#     [liver] 3600/3859 done, avg 0.14s/sample
#     [liver] 3656/3859 done, avg 0.14s/sample
#     [liver] 3704/3859 done, avg 0.14s/sample
#     [liver] 3752/3859 done, avg 0.14s/sample
#     [liver] 3800/3859 done, avg 0.14s/sample
#     [liver] 3856/3859 done, avg 0.14s/sample
#     [liver] 3859/3859 done, avg 0.14s/sample
#   -> [LIVER] Done. Running total time: 11001.83s
# [LUNG] Processing 8992/8992 samples (batch_size=8, use_true_label=True)...
#     [lung] 56/8992 done, avg 0.14s/sample
#     [lung] 104/8992 done, avg 0.14s/sample
#     [lung] 152/8992 done, avg 0.14s/sample
#     [lung] 200/8992 done, avg 0.14s/sample
#     [lung] 256/8992 done, avg 0.14s/sample
#     [lung] 304/8992 done, avg 0.14s/sample
#     [lung] 352/8992 done, avg 0.14s/sample
#     [lung] 400/8992 done, avg 0.14s/sample
#     [lung] 456/8992 done, avg 0.14s/sample
#     [lung] 504/8992 done, avg 0.14s/sample
#     [lung] 552/8992 done, avg 0.14s/sample
#     [lung] 600/8992 done, avg 0.14s/sample
#     [lung] 656/8992 done, avg 0.14s/sample
#     [lung] 704/8992 done, avg 0.14s/sample
#     [lung] 752/8992 done, avg 0.14s/sample
#     [lung] 800/8992 done, avg 0.14s/sample
#     [lung] 856/8992 done, avg 0.14s/sample
#     [lung] 904/8992 done, avg 0.14s/sample
#     [lung] 952/8992 done, avg 0.14s/sample
#     [lung] 1000/8992 done, avg 0.14s/sample
#     [lung] 1056/8992 done, avg 0.14s/sample
#     [lung] 1104/8992 done, avg 0.14s/sample
#     [heart] 904/4792 done, avg 0.13s/sample
#     [heart] 952/4792 done, avg 0.13s/sample
#     [heart] 1000/4792 done, avg 0.13s/sample
#     [heart] 1056/4792 done, avg 0.13s/sample
#     [heart] 1104/4792 done, avg 0.13s/sample
#     [heart] 1152/4792 done, avg 0.13s/sample
#     [heart] 1200/4792 done, avg 0.13s/sample
#     [heart] 1256/4792 done, avg 0.13s/sample
#     [heart] 1304/4792 done, avg 0.13s/sample
#     [heart] 1352/4792 done, avg 0.13s/sample
#     [heart] 1400/4792 done, avg 0.13s/sample
#     [heart] 1456/4792 done, avg 0.13s/sample
#     [heart] 1504/4792 done, avg 0.13s/sample
#     [heart] 1552/4792 done, avg 0.13s/sample
#     [heart] 1600/4792 done, avg 0.13s/sample
#     [heart] 1656/4792 done, avg 0.13s/sample
#     [heart] 1704/4792 done, avg 0.13s/sample
#     [heart] 1752/4792 done, avg 0.13s/sample
#     [heart] 1800/4792 done, avg 0.13s/sample
#     [heart] 1856/4792 done, avg 0.13s/sample
#     [heart] 1904/4792 done, avg 0.13s/sample
#     [heart] 1952/4792 done, avg 0.13s/sample
#     [heart] 2000/4792 done, avg 0.13s/sample
#     [heart] 2056/4792 done, avg 0.13s/sample
#     [heart] 2104/4792 done, avg 0.13s/sample
#     [heart] 2152/4792 done, avg 0.13s/sample
#     [heart] 2200/4792 done, avg 0.13s/sample
#     [heart] 2256/4792 done, avg 0.13s/sample
#     [heart] 2304/4792 done, avg 0.13s/sample
#     [heart] 2352/4792 done, avg 0.13s/sample
#     [heart] 2400/4792 done, avg 0.13s/sample
#     [heart] 2456/4792 done, avg 0.13s/sample
#     [heart] 2504/4792 done, avg 0.13s/sample
#     [heart] 2552/4792 done, avg 0.13s/sample
#     [heart] 2600/4792 done, avg 0.13s/sample
#     [heart] 2656/4792 done, avg 0.13s/sample
#     [heart] 2704/4792 done, avg 0.13s/sample
#     [heart] 2752/4792 done, avg 0.13s/sample
#     [heart] 2800/4792 done, avg 0.13s/sample
#     [heart] 2856/4792 done, avg 0.13s/sample
#     [heart] 2904/4792 done, avg 0.13s/sample
#     [heart] 2952/4792 done, avg 0.13s/sample
#     [heart] 3000/4792 done, avg 0.13s/sample
#     [heart] 3056/4792 done, avg 0.13s/sample
#     [heart] 3104/4792 done, avg 0.13s/sample
#     [heart] 3152/4792 done, avg 0.13s/sample
#     [heart] 3200/4792 done, avg 0.13s/sample
#     [heart] 3256/4792 done, avg 0.13s/sample
#     [heart] 3304/4792 done, avg 0.13s/sample
#     [heart] 3352/4792 done, avg 0.13s/sample
#     [heart] 3400/4792 done, avg 0.13s/sample
#     [heart] 3456/4792 done, avg 0.13s/sample
#     [heart] 3504/4792 done, avg 0.13s/sample
#     [heart] 3552/4792 done, avg 0.13s/sample
#     [heart] 3600/4792 done, avg 0.13s/sample
#     [heart] 3656/4792 done, avg 0.13s/sample
#     [heart] 3704/4792 done, avg 0.13s/sample
#     [heart] 3752/4792 done, avg 0.13s/sample
#     [heart] 3800/4792 done, avg 0.13s/sample
#     [heart] 3856/4792 done, avg 0.13s/sample
#     [heart] 3904/4792 done, avg 0.13s/sample
#     [heart] 3952/4792 done, avg 0.13s/sample
#     [heart] 4000/4792 done, avg 0.13s/sample
#     [heart] 4056/4792 done, avg 0.13s/sample
#     [heart] 4104/4792 done, avg 0.13s/sample
#     [heart] 4152/4792 done, avg 0.13s/sample
#     [heart] 4200/4792 done, avg 0.13s/sample
#     [heart] 4256/4792 done, avg 0.13s/sample
#     [heart] 4304/4792 done, avg 0.13s/sample
#     [heart] 4352/4792 done, avg 0.13s/sample
#     [heart] 4400/4792 done, avg 0.13s/sample
#     [heart] 4456/4792 done, avg 0.13s/sample
#     [heart] 4504/4792 done, avg 0.13s/sample
#     [heart] 4552/4792 done, avg 0.13s/sample
#     [heart] 4600/4792 done, avg 0.13s/sample
#     [heart] 4656/4792 done, avg 0.13s/sample
#     [heart] 4704/4792 done, avg 0.13s/sample
#     [heart] 4752/4792 done, avg 0.13s/sample
#     [heart] 4792/4792 done, avg 0.13s/sample
#   -> [HEART] Done. Running total time: 12546.79s
#
# Gradient analysis done. Total time: 12546.8s
# Samples processed: {'bladder': 7615, 'brain': 19154, 'bone': 25169, 'limb': 17396, 'kidney': 7262, 'liver': 3859, 'lung': 8992, 'heart': 4792}
# Pickle results saved before plotting: /content/drive/MyDrive/aging_prediction_results/qwen3_1_7b_gradient_importance_results.pkl
# JSON summary saved before plotting: /content/drive/MyDrive/aging_prediction_results/qwen3_1_7b_gradient_importance_results.json

# %% [markdown]
# ## 10. Reload Saved Results (Optional)

# %%
# Run this cell when you only want to change plots after a completed gradient run.
# It lets you restart the runtime and skip model loading/gradient computation if the pickle exists.
LOAD_SAVED_RESULTS = False

if LOAD_SAVED_RESULTS or 'full_results' not in globals():
    if not os.path.exists(RESULTS_PKL):
        raise FileNotFoundError(f'No saved results found at: {RESULTS_PKL}')
    with open(RESULTS_PKL, 'rb') as f:
        full_results = pickle.load(f)
    print(f'Loaded saved gradient results from: {RESULTS_PKL}')
else:
    print('Using full_results already in memory.')

print('Samples processed:', full_results.get('samples_processed', {}))
print(f"Gradient runtime stored in results: {full_results.get('total_time', 0.0):.1f}s")
# Out:
# Using full_results already in memory.
# Samples processed: {'bladder': 7615, 'brain': 19154, 'bone': 25169, 'limb': 17396, 'kidney': 7262, 'liver': 3859, 'lung': 8992, 'heart': 4792}
# Gradient runtime stored in results: 12546.8s

# %% [markdown]
# ## 11. Visualize and Summarize

# %%
if 'full_results' not in globals():
    raise RuntimeError('full_results is not loaded. Run the gradient cell or the reload cell first.')

print('Generating visualizations from saved/in-memory results...')
global_top_scores_full = visualize_results(
    full_results,
    ORGAN_KEYS,
    out_dir=PLOT_OUT_DIR,
    top_n=PLOT_TOP_N,
    bar_color=PLOT_BAR_COLOR,
    wordcloud_cmap=PLOT_WORDCLOUD_CMAP,
    figsize=PLOT_FIGSIZE,
)

print('\nRunning organ specificity analysis...')
specificity_results = analyze_organ_specificity(full_results, ORGAN_KEYS, topk=PLOT_TOP_N, out_dir=PLOT_OUT_DIR)

print('\n' + '=' * 70)
print(f'SUMMARY: TOP-{PLOT_TOP_N} TOKENS PER ORGAN (by average gradient score)')
print('=' * 70)
for organ in ORGAN_KEYS:
    src = full_results.get('organ_scores_avg', {})
    if organ not in src:
        continue
    top_tokens = Counter(src[organ]).most_common(PLOT_TOP_N)
    print(f'\n[{organ.upper()}]')
    hdr = f"  {'Rank':<5} {'Token':<30} {'Avg Grad Score':>16}  {'Freq (total)':>12}"
    print(hdr)
    print('  ' + '-' * (len(hdr) - 2))
    freq_src = full_results.get('organ_freq', {}).get(organ, {})
    for rank, (token, score) in enumerate(top_tokens, 1):
        freq = freq_src.get(token, 0)
        print(f'  {rank:<5} {token:<30} {score:>16.6f}  {freq:>12}')

print('\n' + '=' * 70)
print(f'SUMMARY: TOP-{PLOT_TOP_N} TOKENS GLOBAL (by average gradient score, all organs)')
print('=' * 70)
global_avg_top = Counter(full_results.get('global_scores_avg', {})).most_common(PLOT_TOP_N)
hdr = f"  {'Rank':<5} {'Token':<30} {'Avg Grad Score':>16}  {'Total Freq':>10}  {'Organs':>6}"
print(hdr)
print('  ' + '-' * (len(hdr) - 2))
token_organ_count = specificity_results.get('token_organ_count', {})
global_freq = full_results.get('global_freq', {})
for rank, (token, score) in enumerate(global_avg_top, 1):
    freq = global_freq.get(token, 0)
    n_organs = token_organ_count.get(token, '?')
    print(f'  {rank:<5} {token:<30} {score:>16.6f}  {freq:>10}  {n_organs:>6}')

print('\n' + '=' * 70)
print(f'SUMMARY: UNIVERSAL TOKENS (in top-{PLOT_TOP_N} for all organs)')
print('=' * 70)
universal = specificity_results.get('universal_tokens', [])
print(f'  Total: {len(universal)}')
for i, token in enumerate(universal, 1):
    print(f"  {i:>3}. '{token}'")

print('\n' + '=' * 70)
print(f"SUMMARY: ORGAN-EXCLUSIVE TOKENS (unique to each organ's top-{PLOT_TOP_N})")
print('=' * 70)
exclusive = specificity_results.get('exclusive_tokens', {})
for organ in ORGAN_KEYS:
    excl = exclusive.get(organ, [])
    print(f'\n  [{organ.upper()}] {len(excl)} exclusive tokens:')
    for i, token in enumerate(excl, 1):
        score = full_results.get('organ_scores_avg', {}).get(organ, {}).get(token, 0)
        print(f"    {i:>3}. '{token}'  (avg score: {score:.6f})")

if 'torch_xla' in globals():
    torch_xla.sync()
print('\n' + '=' * 70)
print('PLOTTING + ORGAN SPECIFICITY COMPLETE')
print('=' * 70)
# Out:
# Generating visualizations from saved/in-memory results...
#
# ============================================================
# VISUALIZATION RESULTS
# ============================================================
# Samples processed: {'bladder': 7615, 'brain': 19154, 'bone': 25169, 'limb': 17396, 'kidney': 7262, 'liver': 3859, 'lung': 8992, 'heart': 4792}
# Total time: 12546.79s
#
# --- Top 100 tokens by frequency (all organs) ---
#   'three': 157645
#   'two': 84687
#   ':': 49383
#   'Ċ': 42688
#   'one': 29514
#   'four': 26250
#   'ten': 24373
#   'H3f3a': 22963
#   'Rn45s': 21663
#   'Ubb': 19210
#   'Srsf5': 19095
#   'seven': 18113
#   'five': 17433
#   'Myl6': 17306
#   'Rpl31': 0.1358
#   'Igfbp6': 0.1314
#   'Class': 0.1302
#   'Brp44': 0.1290
#   'Ifi27l1': 0.1287
#   'Slpi': 0.1272
#   'Sparc': 0.1251
#   'Cd24a': 0.1227
#   'Car2': 0.1225
#   'Serf2': 0.1204
#   'Atp5l': 0.1191
#   'Bsg': 0.1185
#   'Gender': 0.1165
#   'Fau': 0.1144
#   'Col5a2': 0.1107
#   'Col6a3': 0.1089
#   'Ndufa7': 0.1083
#   'Isg15': 0.1080
#   'Btg2': 0.1065
#   'H2afj': 0.1064
#   'Rps9': 0.1053
#   'Cxcl14': 0.0990
#   'Mfap5': 0.0986
#   'Hmox1': 0.0968
#   'A130040M12Rik': 0.0953
#   'Hba-a1': 0.0946
#   'H2-Q4': 0.0942
#   'H3f3b': 0.0923
#   'Hspg2': 0.0922
#   'Col6a1': 0.0904
#   'Rps27a': 0.0902
#   'Bcl3': 0.0900
#   'Tpt1': 0.0892
#   'Meg3': 0.0877
#   'Beta-s': 0.0875
#   'Sec61g': 0.0875
#   'Hbb-b2': 0.0873
#   'Actn1': 0.0869
#   'Psma2': 0.0862
#   'Hist1h2bc': 0.0862
#   'Hist1h1c': 0.0860
#   'Ptp4a1': 0.0858
#   'P2ry12': 0.0858
#   'Serpine2': 0.0855
#   'Clk1': 0.0855
#   'Itm2b': 0.0854
#   'E2f2': 0.0846
#   'Igf1': 0.0839
#   'Cst3': 0.0839
#   'Hbb-b1': 0.0833
#   'Pabpc1': 0.0827
#   'Sec62': 0.0826
#   'Cygb': 0.0823
#   'Tfrc': 0.0816
#   'Col5a1': 0.0810
#   'Nudt4': 0.0806
#   'Sgk1': 0.0791
#   'Slc4a1': 0.0790
#   'Serpina3n': 0.0788
#   'Mrgpra2b': 0.0783
#   'Uba52': 0.0781
#   'nine': 0.0776
#   'Akirin2': 0.0776
#   'Slc25a37': 0.0772
#   'Wbp2': 0.0767
#   'Gfpt2': 0.0765
#   'Creg1': 0.0764
#   'Mfap2': 0.0762
#   'Gpnmb': 0.0759
#   'Hist1h1d': 0.0757
#   'Cp': 0.0756
#   'Tspan4': 0.0752
#   'Smap1': 0.0748
# --- Word cloud (all organs, by total score) ---
# ============================================================
# VISUALIZATION COMPLETE
# ============================================================
#
# Running organ specificity analysis...
#
# ============================================================
# ORGAN SPECIFICITY ANALYSIS
# ============================================================
#
# Tokens in top-100 for ALL 8 organs (2 tokens):
#   'two'
#   'three'
#
# Organ-exclusive tokens (unique to each organ's top-k):
#   [BLADDER] 52 exclusive: ['Gsdmc2', 'Nrip1', 'Plat', 'Slc14a1', 'Ivl', '2010109K11Rik', 'Gm973', 'Unc5b', 'Snhg11', 'Aldh3a1', 'Efemp1', 'Nipal4', 'Rassf6', 'Npdc1', 'Bmpr1a', 'Adam23', 'Irf6', 'Itgb4', 'Gpa33', 'Slc7a11']
#   [BRAIN] 72 exclusive: ['Dync1li1', 'Ptms', 'Cd81', 'Aip', 'Ndufa3', 'Ctsb', 'Lamp1', 'Ctss', 'seven', 'Cd68', 'Arhgap5', 'Mrto4', 'Fbxo25', 'Calr', 'C1qb', 'Baz1b', 'P2ry12', 'Adprhl2', 'Gars', 'Dcaf7']
#   [BONE] 74 exclusive: ['Gender', 'Akirin2', 'Ppp1r10', 'Cflar', 'Mmp9', 'Creg1', 'Gpcpd1', 'Slpi', 'Lasp1', 'BC031781', 'Herc4', 'Atp5l', 'Eif4ebp2', 'Rb1cc1', 'March2', 'Smap1', 'Cdk12', 'Beta-s', 'Smek2', 'Qsox1']
#   [LIMB] 46 exclusive: ['Ptx3', 'Has1', 'Myoc', 'Retnla', 'Rps26', 'Isg15', 'Tnfaip6', 'Thbs4', 'Arid5a', 'Angptl1', 'Nop14', 'Ccl19', 'Bcl3', 'Prelp', 'Lim', 'Igfbp3', 'Rian', 'Mfap4', 'C3', 'Uba52']
#   [KIDNEY] 77 exclusive: ['Cml1', 'Tmigd1', 'Slc27a2', 'Tstd1', 'Nat8', 'Gss', '1700016C15Rik', 'Hoxb7', '2610017I09Rik', 'Cyp4a31', 'C130074G19Rik', 'Slc5a10', 'Iyd', 'Akr1c21', 'Slc18a1', 'Pecr', 'Slc25a16', '0610005C13Rik', 'Slc13a2', 'BC089597']
#   [LIVER] 66 exclusive: ['Tfec', 'Pklr', 'Folr2', '2810459M11Rik', 'Clec4f', 'Gm12250', 'Ryr1', 'Fcna', 'Cd207', 'Me1', 'Timd4', 'Dok2', 'Acaca', 'Cd14', 'Soat1', 'Bhmt', 'AI606473', 'Cyp2c40', 'Ccl12', 'Mosc1']
#   [LUNG] 58 exclusive: ['Macf1', 'Ptpn18', 'Gm15421', 'Arpc2', 'Gltscr2', 'Evl', 'G0s2', 'Arpc1b', 'Stat1', 'Ifi27l2a', 'Rpl13a', 'Wtap', 'Igfbp7', 'Tuba1a', 'Rpl37a', 'Arf3', 'Emp2', 'Npm1', 'Cnn2', 'Rbm3']
#   [HEART] 52 exclusive: ['Acer2', 'Sdpr', 'Elk3', 'BC002163', 'Ly6c1', 'Pdlim3', 'Ctnnbip1', 'Mb', 'Dcbld1', 'Rassf9', 'Iigp1', 'Heart', 'Lysmd2', 'Ttll7', 'Prex2', 'Nppa', 'Gm12191', 'Tmem88', 'Nbeal1', '1190002H23Rik']
#
# --- Frequency-based specificity ---
# Universal by freq (3 tokens): [':', 'two', 'three']
# Exclusive by freq:
#   [BLADDER] 57: ['Gsdmc2', 'Nrip1', 'Plat', 'Slc14a1', 'Ivl', 'Wnt7b', '2010109K11Rik', 'Unc5b', 'Aldh3a1', 'Efemp1', 'Nipal4', 'Rassf6', 'Npdc1', 'Vegfa', 'Bmpr1a', 'Cpeb2', 'Nr1d1', '9230102O04Rik', 'Adam23', 'Irf6']
#   [BRAIN] 75: ['Dync1li1', 'Ptms', 'Cd81', 'Aip', 'Ctsb', 'Lamp1', 'Ctss', 'seven', 'Cd68', 'Arhgap5', 'Anxa5', 'Calr', 'C1qb', 'Baz1b', 'Irf8', 'P2ry12', 'Cnbp', 'Adprhl2', 'Gars', 'Dcaf7']
#   [BONE] 76: ['Gender', 'Akirin2', 'Ppp1r10', 'Mmp9', 'Creg1', 'Gpcpd1', 'Slpi', 'Lasp1', 'BC031781', 'H2-T23', 'Atp5l', 'Atp5b', 'Cd47', 'Rb1cc1', 'March2', 'Smap1', 'Cdk12', 'Beta-s', 'Smek2', 'Actn1']
#   [LIMB] 46: ['Ptx3', 'Has1', 'Myoc', 'Fbn1', 'Tnfaip6', 'Col6a2', 'Thbs4', 'Arid5a', 'Angptl1', 'Nop14', 'Ccl19', 'Bcl3', 'Prelp', 'Lim', 'Smoc2', 'Uba52', 'C3', 'Mnda', 'Mfap4', 'Rpl31']
#   [KIDNEY] 84: ['Cml1', 'Tmigd1', 'Ddah1', 'Slc27a2', 'Tstd1', 'Nat8', 'Gss', '1700016C15Rik', 'Wdfy1', 'Gstt2', 'Cyp4a31', 'C130074G19Rik', 'Slc5a10', 'Iyd', 'Tpmt', 'Akr1c21', 'Nuak2', 'Slc18a1', 'Pecr', 'Slc25a16']
#   [LIVER] 76: ['Tfec', 'Pklr', 'Folr2', 'Clec4f', 'Ryr1', 'G530011O06Rik', 'Fcna', 'Cd207', 'Timd4', 'Dok2', 'Acaca', 'Soat1', 'Bhmt', 'Akr1c14', 'Cxcl13', 'AI606473', 'Cyp2c40', 'Ccl12', 'Il1rn', 'Mosc1']
#   [LUNG] 63: ['Macf1', 'Ptpn18', 'Gm15421', 'Arpc2', 'Gltscr2', 'Arpc1b', 'Evl', 'G0s2', 'Stat1', 'Srgn', 'Ifi27l2a', 'Rpl13a', 'Wtap', 'Nfkbia', 'Igfbp7', 'Hmha1', 'Tuba1a', 'Rpl37a', 'Arf3', 'Npm1']
#   [HEART] 62: ['Sept4', 'Cd300lg', 'Kitl', 'Sdpr', 'Acer2', 'Elk3', 'BC002163', 'Ly6c1', 'Fmo2', 'Ctnnbip1', 'Mb', 'Zbtb4', 'Clec1a', 'Col15a1', 'Rassf9', 'Heart', 'Lysmd2', 'Gpr4', 'Prex2', 'Nppa']
# ======================================================================
# SUMMARY: TOP-100 TOKENS PER ORGAN (by average gradient score)
# ======================================================================
#
# [BLADDER]
#   Rank  Token                            Avg Grad Score  Freq (total)
#   -------------------------------------------------------------------
#   1     Nr1d1                                  0.423796          4842
#   2     three                                  0.330085         12042
#   3     Plac9                                  0.263328          3139
#   4     Col3a1                                 0.250040          3310
#   5     two                                    0.213892          7095
#   6     Col1a1                                 0.211414          3190
#   7     Dbp                                    0.164914          1810
#   8     Gpnmb                                  0.151837          3378
#   9     Vegfa                                  0.147791          2841
#   10    one                                    0.146953          4192
#   11    Klf5                                   0.145256          3694
#   12    Slc7a11                                0.141041          1772
#   13    Serpina3n                              0.139328          2346
#   14    Col1a2                                 0.135112          3077
#   15    Serpinh1                               0.107564          2710
#   16    Gsdmc2                                 0.104363          2291
#   17    Blcap                                  0.101753          2161
#   18    Nr1d2                                  0.101622          2724
#   19    Ifitm1                                 0.099832          1888
#   20    Dcn                                    0.099321          2671
#   21    Cxcl14                                 0.097977          2516
#   22    Ptp4a1                                 0.091133          2366
#   78    H3f3b                                  0.014079          1545
#   79    Hspa8                                  0.013999          1656
#   80    Fam176b                                0.013943          1050
#   81    Cox7a2                                 0.013838          1041
#   82    Ctsb                                   0.013795          1504
#   83    Commd4                                 0.013754          1061
#   84    Adam17                                 0.013700          1100
#   85    Celf1                                  0.013602          1029
#   86    Ppp3r1                                 0.013433           813
#   87    Chsy1                                  0.013198          1070
#   88    Cyb561d2                               0.013189           960
#   89    Dync1li1                               0.013072           997
#   90    Baz1b                                  0.013070          1024
#   91    Ndufa3                                 0.012916           931
#   92    Agmo                                   0.012806          1020
#   93    Actb                                   0.012708          1331
#   94    Nr1d1                                  0.012598           408
#   95    Fbxo25                                 0.012542           728
#   96    Arhgap5                                0.012541          1173
#   97    Hist1h2bc                              0.012390           985
#   98    Ptms                                   0.012336          1024
#   99    Dynll1                                 0.012260          1111
#   100   Ctdnep1                                0.012226           820
#
# [BONE]
#   Rank  Token                            Avg Grad Score  Freq (total)
#   -------------------------------------------------------------------
#   1     three                                  0.386672         45987
#   2     Srsf5                                  0.324270         18493
#   3     Gm1821                                 0.297318         11889
#   4     H3f3a                                  0.248756         17331
#   5     two                                    0.248131         28031
#   6     Top1                                   0.176074         14279
#   7     Ċ                                      0.168737         16957
#   8     Ifi27l1                                0.167970         10836
#   9     Ubb                                    0.167769         16221
#   10    four                                   0.161859         15925
#   11    D4Wsu53e                               0.134665         13942
#   12    :                                      0.131767         16186
#   13    Apol11b                                0.130817          5114
#   14    Mar                                    0.127500          6041
#   15    Retnlg                                 0.125788         13112
#   16    Hba-a1                                 0.121095          8802
#   17    Myl6                                   0.117850         12801
#   18    Ndufa7                                 0.114114         10119
#   19    Car2                                   0.109196         10972
#   20    Atp5l                                  0.103557         10960
#   21    Brp44                                  0.102144         11998
#   22    Slpi                                   0.101686         11964
#   23    one                                    0.099664         10196
#   24    Cd24a                                  0.099179         11531
#   25    Mrgpra2b                               0.095214          7375
#   26    H2-D1                                  0.094699         11074
#   27    Bsg                                    0.093640         10302
#   28    Glul                                   0.092238          7969
#   29    Tfrc                                   0.083424          7485
#   30    Hist1h2bc                              0.083233          7142
#   31    H2afj                                  0.082093          8843
#   32    Btg2                                   0.079092          9261
#   33    Class                                  0.078769          4730
#   34    E2f2                                   0.077838          7858
#   35    Gabarap                                0.076346          9001
#   36    Slc4a1                                 0.076209          7436
#   37    Actn1                                  0.075830          7443
#   38    Ccl5                                   0.075327          3727
#   39    Hbb-b1                                 0.074706          7730
#   40    Ier3                                   0.073387          4405
#   41    Hist1h1d                               0.073054          7022
#   42    Wbp2                                   0.073040          6904
#   43    Nudt4                                  0.071016          7555
#   44    Sec61g                                 0.070662          8200
#   45    Beta-s                                 0.069478          8192
#   46    1700037H04Rik                          0.067649          6356
#   47    Hbb-b2                                 0.066921          8205
#   48    Akirin2                                0.066843          6716
#   49    Hist1h1c                               0.065751          7658
#   50    Serf2                                  0.065678          7565
#   51    Psma2                                  0.065083          7962
#   52    Ppil4                                  0.063837          5973
#   53    Cdk12                                  0.062556          5086
#   83    Pth1r                                  0.044242          1470
#   84    Hs6st1                                 0.044134          1226
#   85    Apob                                   0.043967           846
#   86    Il1b                                   0.043650           770
#   87    2610017I09Rik                          0.043619           827
#   88    Slc13a3                                0.043564           845
#   89    Klhdc8a                                0.043141           842
#   90    Fgf1                                   0.042406          1415
#   91    Hoxb7                                  0.042105          1122
#   92    Tmigd1                                 0.042040          1413
#   93    Slc5a8                                 0.041900          1123
#   94    AI317395                               0.041291          1354
#   95    ph                                     0.040942           499
#   96    Gss                                    0.040846          1390
#   97    Cyp4a31                                0.040615          1257
#   98    Slc6a18                                0.040534          1322
#   99    1700016C15Rik                          0.039976          1186
#   100   Spink3                                 0.039343          1339
#
# [LIVER]
#   Rank  Token                            Avg Grad Score  Freq (total)
#   -------------------------------------------------------------------
#   1     three                                  0.516067          9291
#   2     Gsta3                                  0.360945          1878
#   3     Ahsg                                   0.305939          2458
#   4     Fabp1                                  0.285532          2178
#   5     Azgp1                                  0.252315          1789
#   6     Cxcl13                                 0.223569          1703
#   7     Serpina1a                              0.216580          2222
#   8     Apob                                   0.215255          1766
#   9     Ryr1                                   0.208947          1110
#   10    Gc                                     0.203971          2061
#   11    Cfhr2                                  0.203864          1337
#   12    two                                    0.199597          3207
#   13    Hmgcs2                                 0.195352          1762
#   14    Cyp2c40                                0.183420          1181
#   15    Cyp4a14                                0.180873          1298
#   16    C4bp                                   0.172397          1543
#   17    Serpina3k                              0.168325          2150
#   18    Pigr                                   0.167171          1059
#   19    Cyp2b9                                 0.160413           782
#   20    Clec4f                                 0.160408          1938
#   21    C6                                     0.157968          1116
#   22    Cd207                                  0.150708          1599
#   23    Vsig4                                  0.149081          1961
#   24    Folr2                                  0.143842          1899
#   25    Dio1                                   0.142073          1038
# ...
#      60. 'Cfdp1'  (avg score: 0.023551)
#      61. 'ten'  (avg score: 0.226594)
#      62. 'Hexb'  (avg score: 0.026352)
#      63. 'Ctsl'  (avg score: 0.024306)
#      64. 'Actb'  (avg score: 0.012708)
#      65. 'Cyb561d2'  (avg score: 0.013189)
#      66. 'Calm2'  (avg score: 0.022012)
#      67. 'Lars2'  (avg score: 0.030067)
#      68. 'Itgb5'  (avg score: 0.068595)
#      69. 'Pou2f2'  (avg score: 0.014126)
#      70. 'five'  (avg score: 0.215991)
#      71. 'six'  (avg score: 0.050706)
#      72. 'Bzw1'  (avg score: 0.015630)
#
#   [BONE] 74 exclusive tokens:
#       1. 'Gender'  (avg score: 0.054822)
#       2. 'Akirin2'  (avg score: 0.066843)
#       3. 'Ppp1r10'  (avg score: 0.050915)
#       4. 'Cflar'  (avg score: 0.048269)
#       5. 'Mmp9'  (avg score: 0.054889)
#       6. 'Creg1'  (avg score: 0.054043)
#       7. 'Gpcpd1'  (avg score: 0.058275)
#       8. 'Slpi'  (avg score: 0.101686)
#       9. 'Lasp1'  (avg score: 0.053247)
#      10. 'BC031781'  (avg score: 0.047003)
#      11. 'Herc4'  (avg score: 0.055412)
#      12. 'Atp5l'  (avg score: 0.103557)
# TOP-2048 GLOBAL AVERAGE GRADIENT SCORE TOKENS
# Ranked list of tokens by avg gradient importance across all organs.
# ============================================================
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

_gsa = full_results.get('global_scores_avg', {})
if not _gsa:
    print('[WARN] global_scores_avg empty — run Block 2 first.')
else:
    top2048 = Counter(_gsa).most_common(2048)
    n_unique = len(_gsa)

    # ── Text table (all 2048) ─────────────────────────────────────────────────
    print('=' * 70)
    print('TOP-2048 TOKENS BY AVERAGE GRADIENT IMPORTANCE (ALL ORGANS)')
    print('=' * 70)
    print(f'Total unique tokens tracked: {n_unique}  |  Reporting top {len(top2048)}\n')
    hdr = '{:<6} {:<35} {:>18}'.format('Rank', 'Token', 'Avg Grad Score')
    print(hdr)
    print('-' * len(hdr))
    for rank, (token, score) in enumerate(top2048, 1):
        print(f'{rank:<6} {token:<35} {score:>18.6f}')
    print('\n' + '=' * 70)

    # ── Bar chart: top-128 by avg gradient score ──────────────────────────────
    top100 = top2048[:100]
    tokens_100  = [t for t, _ in top100]
    scores_100  = [s for _, s in top100]
    # reverse for horizontal bar (highest at top)
    tokens_100r = tokens_100[::-1]
    scores_100r = scores_100[::-1]

    fig, ax = plt.subplots(figsize=(14, 40))
    bars = ax.barh(range(len(tokens_100r)), scores_100r, color='steelblue')
    ax.set_yticks(range(len(tokens_100r)))
    ax.set_yticklabels(tokens_100r, fontsize=9)
    ax.set_xlabel('Avg Gradient Score (all organs)', fontsize=11)
    ax.set_title('Top-100 Tokens — Avg Gradient Importance (All Organs)', fontsize=13)
    # Annotate each bar with its rank
    for i, (bar, score) in enumerate(zip(bars, scores_100r)):
        rank = len(top100) - i
        ax.text(bar.get_width() * 1.005, bar.get_y() + bar.get_height() / 2,
                f'#{rank}  {score:.4f}', va='center', fontsize=7.5)
    plt.tight_layout()
    plt.show()

    # ── Score distribution (log-scale histogram) ─────────────────────────────
    all_scores = [s for _, s in top2048]
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.hist(all_scores, bins=80, color='teal', edgecolor='white', linewidth=0.4)
    ax.set_yscale('log')
    ax.set_xlabel('Avg Gradient Score', fontsize=11)
    ax.set_ylabel('Count (log scale)', fontsize=11)
    ax.set_title('Distribution of Avg Gradient Scores — Top-2048 Tokens', fontsize=12)
    plt.tight_layout()
    plt.show()

    # ── Cumulative score coverage ─────────────────────────────────────────────
    total_score = sum(all_scores)
    cum_frac = np.cumsum(all_scores) / total_score
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.plot(range(1, len(cum_frac) + 1), cum_frac * 100, color='darkorange', linewidth=1.5)
    for pct, color in [(50, 'blue'), (80, 'green'), (95, 'red')]:
        idx = np.searchsorted(cum_frac, pct / 100)
        ax.axvline(idx + 1, linestyle='--', color=color, linewidth=1,
                   label=f'{pct}% coverage @ rank {idx+1}')
    ax.set_xlabel('Token rank (by avg score)', fontsize=11)
    ax.set_ylabel('Cumulative score coverage (%)', fontsize=11)
    ax.set_title('Cumulative Score Coverage — Top-2048 Tokens', fontsize=12)
    ax.legend(fontsize=9)
    plt.tight_layout()
    plt.show()

    print(f'\nScore statistics:')
    print(f'  Top-1  token: {top2048[0][0]!r:35s}  score={top2048[0][1]:.6f}')
    print(f'  Top-10 cumulative fraction: {cum_frac[9]*100:.1f}%')
    print(f'  Top-100 cumulative fraction: {cum_frac[99]*100:.1f}%')
    if len(cum_frac) >= 2048:
        print(f'  Top-2048 cumulative fraction: {cum_frac[2047]*100:.1f}%')
# Out:
# ======================================================================
# TOP-2048 TOKENS BY AVERAGE GRADIENT IMPORTANCE (ALL ORGANS)
# ======================================================================
# Total unique tokens tracked: 21441  |  Reporting top 2048
#
# Rank   Token                                   Avg Grad Score
# -------------------------------------------------------------
# 1      three                                         0.354798
# 2      two                                           0.208766
# 3      Ċ                                             0.119347
# 4      :                                             0.105354
# 5      Col1a1                                        0.098862
# 6      Srsf5                                         0.088030
# 7      Gm1821                                        0.087198
# 8      one                                           0.083845
# 9      H3f3a                                         0.082641
# 10     four                                          0.066309
# 11     Class                                         0.058979
# 12     Rn45s                                         0.052728
# 13     Ubb                                           0.051796
# 14     Ifi27l1                                       0.048389
# 15     Top1                                          0.047400
# 16     ten                                           0.046055
# 17     Dbp                                           0.045825
# 18     Dcn                                           0.044696
# 19     Nr1d1                                         0.044415
# 20     five                                          0.043900
# 21     Myl6                                          0.042535
# 22     Socs3                                         0.041481
# 23     Col6a3                                        0.041164
# 24     Glul                                          0.040066
# 25     Col5a2                                        0.039815
# 26     D4Wsu53e                                      0.039371
# 27     Igfbp6                                        0.039149
# 28     Gabarap                                       0.038524
# 29     seven                                         0.038086
# 30     Serpina3n                                     0.037255
# 31     Rps29                                         0.037050
# 32     Rpl31                                         0.036850
# 33     Apol11b                                       0.035019
# 34     Plac9                                         0.034099
# 35     Mar                                           0.034052
# 36     Retnlg                                        0.033604
# 37     Rps24                                         0.033068
# 38     Eln                                           0.032997
# 39     Hba-a1                                        0.032773
# 40     H2-D1                                         0.032719
# 41     Meg3                                          0.032317
# 42     Gender                                        0.032297
# 43     eight                                         0.032024
# 44     Ndufa7                                        0.030634
# 45     C1qtnf6                                       0.030615
# 46     Car2                                          0.030577
# 47     Wdfy1                                         0.030314
# 48     Col3a1                                        0.030040
# 49     Rps9                                          0.029784
# 50     Sparc                                         0.029409
# 51     Cxcl14                                        0.028350
# 52     Atp5l                                         0.028168
# 53     Serf2                                         0.028105
# 54     Hmox1                                         0.027620
# 55     Brp44                                         0.027564
# 56     Egr1                                          0.027362
# 57     Slpi                                          0.027226
# 58     Igf1                                          0.026990
# 59     Bsg                                           0.026663
# 60     Cd24a                                         0.026557
# 61     Gsta3                                         0.026409
# 62     Col5a1                                        0.025961
# 63     A130040M12Rik                                 0.025915
# 64     H2-Q4                                         0.025914
# 65     Ptp4a1                                        0.025795
# 66     Bcl3                                          0.025734
# 67     Isg15                                         0.025679
# 68     Mrgpra2b                                      0.025447
# 69     Timp1                                         0.025261
# 70     Ifitm1                                        0.025004
# 71     Rps28                                         0.024824
# 72     Mfap5                                         0.024759
# 73     Hist1h2bc                                     0.024748
# 1989   BC017158                                      0.002733
# 1990   Ppp3r1                                        0.002730
# 1991   Syngr1                                        0.002728
# 1992   Enpp3                                         0.002728
# 1993   Pxmp4                                         0.002725
# 1994   Asb3                                          0.002721
# 1995   Oma1                                          0.002720
# 1996   Ubd                                           0.002717
# 1997   Atrnl1                                        0.002717
# 1998   2310061J03Rik                                 0.002715
# 1999   Plk2                                          0.002712
# 2000   Icos                                          0.002711
# 2001   Atp6v1g1                                      0.002710
# 2002   Slc39a10                                      0.002710
# 2003   Kng1                                          0.002709
# 2004   Kpna1                                         0.002707
# 2005   Nufip2                                        0.002706
# 2006   Gcc1                                          0.002704
# 2007   Ccdc134                                       0.002703
# 2008   Pgcp                                          0.002702
# 2009   Ptgis                                         0.002701
# 2010   Scnn1b                                        0.002701
# 2011   Art4                                          0.002699
# 2012   Sprr2b                                        0.002699
# 2013   Lox                                           0.002699
# 2014   Tnpo1                                         0.002697
# 2015   Tnfaip8l1                                     0.002695
# 2016   Bcr                                           0.002695
# 2017   Gsta4                                         0.002694
# 2018   Sh3bp4                                        0.002693
# 2019   Klhl25                                        0.002690
# 2020   Alb                                           0.002688
# 2021   Dennd2c                                       0.002683
# 2022   Eid3                                          0.002683
# 2023   Chsy1                                         0.002682
# 2024   Scarb1                                        0.002681
# 2025   Cyb561d2                                      0.002681
# 2026   1700094D03Rik                                 0.002679
# 2027   Sult1d1                                       0.002677
# 2028   Etnk2                                         0.002677
# 2029   Dpys                                          0.002676
# 2030   Ccdc64b                                       0.002673
# 2031   Nicn1                                         0.002672
# 2032   4933408B17Rik                                 0.002672
# 2033   Btrc                                          0.002671
# 2034   1600027N09Rik                                 0.002667
# 2035   Lysmd2                                        0.002665
# 2036   Rasal2                                        0.002664
# 2037   4632427E13Rik                                 0.002664
# 2038   Zfp955b                                       0.002663
# 2039   Pla2g16                                       0.002663
# 2040   Nmi                                           0.002658
# 2041   Baz1b                                         0.002656
# 2042   X99384                                        0.002656
# 2043   Cnn3                                          0.002655
# 2044   Arf5                                          0.002655
# 2045   Pls3                                          0.002654
# 2046   2310005G13Rik                                 0.002653
# 2047   Arl5b                                         0.002653
# 2048   Kdm5b                                         0.002650
#
# ======================================================================
# Score statistics:
#   Top-1  token: 'three'                              score=0.354798
#   Top-10 cumulative fraction: 8.2%
#   Top-100 cumulative fraction: 25.6%
#   Top-2048 cumulative fraction: 100.0%

# %% [markdown]
# ## 13. Manual Re-save Results

# %%
# Manual re-save cell. The gradient run already saves before plotting.
if 'full_results' not in globals():
    raise RuntimeError('full_results is not loaded. Run the gradient cell or reload saved results first.')

os.makedirs(RESULTS_DIR, exist_ok=True)
with open(RESULTS_PKL, 'wb') as f:
    pickle.dump(full_results, f)
print(f'Re-saved pickle results to: {RESULTS_PKL}')
# Out:
# Re-saved pickle results to: /content/drive/MyDrive/aging_prediction_results/qwen3_1_7b_gradient_importance_results.pkl

# %% [markdown]
# ## 14. Optional Runtime Cleanup

# %%
# Optional: disconnect the Colab runtime after the analysis is saved.
# from google.colab import runtime
# runtime.unassign()
